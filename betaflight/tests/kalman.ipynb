# %%
import socket
import struct
import time

### Connection
# Connect to a Betaflight drone via TCP
host = '192.168.1.2'  # IP address of the drone
port = 5761  # port typically used for TCP-based connections with Betaflight

sock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
sock.connect((host, port))

# %%
### MSP commands
# out messages usually start with 1 (1**)
MSP_STATUS = 101
MSP_RAW_IMU = 102
# in messages usually start with 2 (2**)
MSP_SET_MOTOR = 214

### Main functions
def construct_msp_message(command: int, data: list = []) -> bytearray:
    """Creates expected formatting.

    Command frame format:
    Header: `$M<`
    Body: length of `data` + `command` + `data` values
    Tail: checksum

    Args:
        command (int): MSP command
        data (list, optional): list of params (length is varying). Defaults to [].

    Returns:
        bytearray: command frame
    """
    message = bytearray()
    # header
    message.append(ord('$'))
    message.append(ord('M'))
    message.append(ord('<'))
    # body
    message.append(len(data))
    message.append(command)
    checksum = len(data) ^ command
    for byte in data:
        message.append(byte)
        checksum ^= byte
    # tail
    message.append(checksum)
    return message

def send_msp_message(command: int, data: list = []):
    """Send prepared command via serial

    Args:
        command (int): MSP command
        data (list, optional): list of params. Defaults to [].
    """
    message = construct_msp_message(command, data)
    sock.sendall(message)

def read_msp_response() -> tuple:
    """Read data

    Returns:
        tuple: command code and its values
    """
    header = sock.recv(3)  # read header
    if header != b'$M>':
        return None
    # read body
    data_length = sock.recv(1)[0]
    code = sock.recv(1)[0]
    data = sock.recv(data_length)
    # read tail
    checksum = sock.recv(1)[0]
    # check if the command is of the expected length
    calculated_checksum = data_length ^ code
    for byte in data:
        calculated_checksum ^= byte
    if calculated_checksum != checksum:
        return None

    return (code, data)

def get_raw_imu() -> tuple:
    """Read raw IMU data and decode it as signed 16-bit integers.

    Returns:
        tuple | None: tuple - processed data, None - received data doesn't correspond to sent command
    """
    send_msp_message(MSP_RAW_IMU)  # send request
    time.sleep(0.009)  # wait for reply
    response = read_msp_response()  # get reply

    if response and response[0] == MSP_RAW_IMU:
        # Decode as signed 16-bit integers
        imu = struct.unpack('<9h', response[1])  # AccX, AccY, AccZ, GyroX, GyroY, GyroZ
        #imu = struct.unpack(f'<{len(response[1]) // 2}H', response[1])  # decode
        return imu[:3] # AccX, AccY, AccZ
    return None

# %%
import numpy as np

class PoseEstimator:
    def __init__(self, dt, process_noise, measurement_noise):
        # Time step
        self.dt = dt

        # State vector [position_x, position_y, position_z, velocity_x, velocity_y, velocity_z]
        self.x = np.zeros((6, 1))

        # State transition matrix
        self.A = np.eye(6)
        for i in range(3):
            self.A[i, i + 3] = dt  # Position update from velocity

        # Control matrix for accelerometer input (assumes constant acceleration within dt)
        self.B = np.zeros((6, 3))
        for i in range(3):
            self.B[i + 3, i] = dt

        # Process noise covariance (estimated noise in the system)
        self.Q = process_noise * np.eye(6)

        # Measurement noise covariance (estimated sensor noise)
        self.R = measurement_noise * np.eye(3)

        # Measurement matrix to relate state to position measurements
        self.H = np.zeros((3, 6))
        for i in range(3):
            self.H[i, i] = 1

        # Initial covariance matrix
        self.P = np.eye(6)

    def predict(self, u):
        # Predict the state
        self.x = np.dot(self.A, self.x) + np.dot(self.B, u.reshape(3, 1))  # Reshape u to (3, 1)
        
        # Predict the covariance
        self.P = np.dot(self.A, np.dot(self.P, self.A.T)) + self.Q

    def update(self, z):
        # Measurement residual
        y = z - np.dot(self.H, self.x)
        
        # Residual covariance
        S = np.dot(self.H, np.dot(self.P, self.H.T)) + self.R
        
        # Kalman gain
        K = np.dot(self.P, np.dot(self.H.T, np.linalg.inv(S)))
        
        # Update the state
        self.x = self.x + np.dot(K, y)
        
        # Update the covariance
        I = np.eye(self.P.shape[0])
        self.P = np.dot(I - np.dot(K, self.H), self.P)

    def get_position(self):
        # Return only the current position estimate (x, y, z)
        return self.x[0:3].flatten()

# Parameters
dt = 0.01  # Time step
process_noise = 2.56
measurement_noise = 1.0

# Initialize Kalman filter
pose_estimator = PoseEstimator(dt, process_noise, measurement_noise)

# Simulation loop
while True:
    # Replace `get_raw_imu()` with actual IMU data retrieval
    acceleration = np.array(get_raw_imu())  # Example: get acceleration data [ax, ay, az]
    
    # Ensure the acceleration is a 3-element array (reshape if needed)
    if acceleration.shape[0] != 3:
        raise ValueError("Acceleration input must be a 3-element vector.")

    pose_estimator.predict(u=acceleration)  # Predict with acceleration as control input
    measured_position = np.zeros((3, 1))  # Assuming no external measurement for this example
    pose_estimator.update(z=measured_position)  # Update with "no measurement" to simulate pure integration
    
    # Get and print only the current x, y, z position estimate
    position = pose_estimator.get_position()
    print(f"Position (x, y, z): {position[0]:.2f}, {position[1]:.2f}, {position[2]:.2f}")
# Out:
# Position (x, y, z): 0.00, 0.00, 0.00
# Position (x, y, z): -0.03, 0.04, 0.02
# Position (x, y, z): -0.06, 0.08, 0.04
# Position (x, y, z): -0.06, 0.09, 0.09
# Position (x, y, z): -0.07, 0.09, 0.15
# Position (x, y, z): -0.06, 0.08, 0.21
# Position (x, y, z): -0.06, 0.08, 0.27
# Position (x, y, z): -0.06, 0.07, 0.34
# Position (x, y, z): -0.06, 0.07, 0.40
# Position (x, y, z): -0.06, 0.06, 0.46
# Position (x, y, z): -0.06, 0.06, 0.52
# Position (x, y, z): -0.06, 0.06, 0.58
# Position (x, y, z): -0.06, 0.06, 0.65
# Position (x, y, z): -0.06, 0.05, 0.71
# Position (x, y, z): -0.06, 0.05, 0.77
# Position (x, y, z): -0.06, 0.05, 0.83
# Position (x, y, z): -0.06, 0.04, 0.89
# Position (x, y, z): -0.06, 0.04, 0.95
# Position (x, y, z): -0.06, 0.04, 1.01
# Position (x, y, z): -0.06, 0.04, 1.07
# Position (x, y, z): -0.06, 0.04, 1.13
# Position (x, y, z): -0.06, 0.04, 1.19
# Position (x, y, z): -0.06, 0.04, 1.25
# Position (x, y, z): -0.06, 0.03, 1.31
# Position (x, y, z): -0.06, 0.03, 1.37
# Position (x, y, z): -0.06, 0.03, 1.43
# Position (x, y, z): -0.06, 0.02, 1.48
# Position (x, y, z): -0.06, 0.02, 1.54
# Position (x, y, z): -0.06, 0.02, 1.60
# Position (x, y, z): -0.06, 0.01, 1.66
# Position (x, y, z): -0.06, 0.01, 1.72
# Position (x, y, z): -0.06, 0.01, 1.77
# Position (x, y, z): -0.06, 0.00, 1.83
# Position (x, y, z): -0.06, -0.00, 1.89
# Position (x, y, z): -0.06, -0.01, 1.94
# Position (x, y, z): -0.06, -0.01, 2.00
# Position (x, y, z): -0.06, -0.02, 2.05
# Position (x, y, z): -0.06, -0.02, 2.11
# Position (x, y, z): -0.06, -0.03, 2.16
# Position (x, y, z): -0.06, -0.04, 2.21
# Position (x, y, z): -0.06, -0.04, 2.27
# Position (x, y, z): -0.06, -0.05, 2.32
# Position (x, y, z): -0.06, -0.06, 2.37
# Position (x, y, z): -0.06, -0.07, 2.42
# Position (x, y, z): -0.06, -0.08, 2.47
# Position (x, y, z): -0.05, -0.08, 2.52
# Position (x, y, z): -0.06, -0.09, 2.57
# Position (x, y, z): -0.06, -0.09, 2.62
# Position (x, y, z): -0.05, -0.09, 2.67
# Position (x, y, z): -0.05, -0.10, 2.72
# Position (x, y, z): -0.05, -0.10, 2.77
# Position (x, y, z): -0.05, -0.10, 2.83
# Position (x, y, z): -0.05, -0.10, 2.88
# Position (x, y, z): -0.05, -0.11, 2.93
# Position (x, y, z): -0.05, -0.11, 2.98
# Position (x, y, z): -0.05, -0.11, 3.02
# Position (x, y, z): -0.05, -0.12, 3.07
# Position (x, y, z): -0.05, -0.12, 3.12
# Position (x, y, z): -0.05, -0.12, 3.16
# Position (x, y, z): -0.05, -0.12, 3.21
# Position (x, y, z): -0.05, -0.12, 3.25
# Position (x, y, z): -0.05, -0.13, 3.30
# Position (x, y, z): -0.05, -0.13, 3.34
# Position (x, y, z): -0.05, -0.13, 3.38
# Position (x, y, z): -0.05, -0.13, 3.43
# Position (x, y, z): -0.05, -0.13, 3.47
# Position (x, y, z): -0.05, -0.13, 3.51
# Position (x, y, z): -0.05, -0.14, 3.55
# Position (x, y, z): -0.05, -0.14, 3.59
# Position (x, y, z): -0.04, -0.14, 3.63
# Position (x, y, z): -0.04, -0.15, 3.67
# Position (x, y, z): -0.04, -0.15, 3.71
# Position (x, y, z): -0.04, -0.15, 3.75
# Position (x, y, z): -0.04, -0.16, 3.78
# Position (x, y, z): -0.04, -0.16, 3.82
# Position (x, y, z): -0.04, -0.16, 3.86
# Position (x, y, z): -0.04, -0.16, 3.90
# Position (x, y, z): -0.04, -0.17, 3.93
# Position (x, y, z): -0.04, -0.17, 3.97
# Position (x, y, z): -0.04, -0.18, 4.01
# Position (x, y, z): -0.04, -0.18, 4.04
# Position (x, y, z): -0.04, -0.18, 4.08
# Position (x, y, z): -0.04, -0.19, 4.11
# Position (x, y, z): -0.03, -0.19, 4.15
# Position (x, y, z): -0.03, -0.19, 4.18
# Position (x, y, z): -0.03, -0.20, 4.22
# Position (x, y, z): -0.03, -0.20, 4.25
# Position (x, y, z): -0.03, -0.20, 4.28
# Position (x, y, z): -0.03, -0.21, 4.31
# Position (x, y, z): -0.03, -0.21, 4.34
# Position (x, y, z): -0.03, -0.22, 4.37
# Position (x, y, z): -0.03, -0.22, 4.40
# Position (x, y, z): -0.03, -0.22, 4.43
# Position (x, y, z): -0.03, -0.23, 4.46
# Position (x, y, z): -0.03, -0.23, 4.49
# Position (x, y, z): -0.03, -0.23, 4.52
# Position (x, y, z): -0.03, -0.23, 4.55
# Position (x, y, z): -0.03, -0.23, 4.58
# Position (x, y, z): -0.03, -0.24, 4.60
# Position (x, y, z): -0.03, -0.24, 4.63
# Position (x, y, z): -0.03, -0.24, 4.66
# Position (x, y, z): -0.03, -0.25, 4.68
# Position (x, y, z): -0.03, -0.25, 4.71
# Position (x, y, z): -0.03, -0.25, 4.73
# Position (x, y, z): -0.03, -0.25, 4.76
# Position (x, y, z): -0.03, -0.26, 4.78
# Position (x, y, z): -0.03, -0.26, 4.81
# Position (x, y, z): -0.03, -0.26, 4.83
# Position (x, y, z): -0.03, -0.26, 4.85
# Position (x, y, z): -0.03, -0.27, 4.87
# Position (x, y, z): -0.03, -0.27, 4.89
# Position (x, y, z): -0.03, -0.27, 4.92
# Position (x, y, z): -0.03, -0.27, 4.94
# Position (x, y, z): -0.03, -0.27, 4.96
# Position (x, y, z): -0.03, -0.28, 4.98
# Position (x, y, z): -0.03, -0.28, 5.00
# Position (x, y, z): -0.03, -0.29, 5.02
# Position (x, y, z): -0.03, -0.29, 5.04
# Position (x, y, z): -0.03, -0.30, 5.06
# Position (x, y, z): -0.03, -0.30, 5.08
# Position (x, y, z): -0.03, -0.31, 5.10
# Position (x, y, z): -0.03, -0.31, 5.11
# Position (x, y, z): -0.02, -0.31, 5.13
# Position (x, y, z): -0.02, -0.32, 5.15
# Position (x, y, z): -0.02, -0.32, 5.17
# Position (x, y, z): -0.02, -0.33, 5.19
# Position (x, y, z): -0.02, -0.33, 5.20
# Position (x, y, z): -0.02, -0.34, 5.22
# Position (x, y, z): -0.02, -0.34, 5.24
# Position (x, y, z): -0.02, -0.35, 5.26
# Position (x, y, z): -0.01, -0.35, 5.28
# Position (x, y, z): -0.01, -0.35, 5.30
# Position (x, y, z): -0.01, -0.36, 5.31
# Position (x, y, z): -0.01, -0.36, 5.33
# Position (x, y, z): -0.00, -0.36, 5.35
# Position (x, y, z): -0.00, -0.36, 5.36
# Position (x, y, z): -0.00, -0.37, 5.38
# Position (x, y, z): 0.00, -0.37, 5.40
# Position (x, y, z): 0.00, -0.37, 5.41
# Position (x, y, z): 0.01, -0.38, 5.43
# Position (x, y, z): 0.01, -0.38, 5.44
# Position (x, y, z): 0.01, -0.38, 5.45
# Position (x, y, z): 0.01, -0.39, 5.46
# Position (x, y, z): 0.01, -0.39, 5.48
# Position (x, y, z): 0.01, -0.39, 5.49
# Position (x, y, z): 0.01, -0.40, 5.50
# Position (x, y, z): 0.01, -0.40, 5.51
# Position (x, y, z): 0.01, -0.40, 5.52
# Position (x, y, z): 0.01, -0.41, 5.53
# Position (x, y, z): 0.01, -0.41, 5.54
# Position (x, y, z): 0.01, -0.41, 5.55
# Position (x, y, z): 0.01, -0.41, 5.56
# Position (x, y, z): 0.01, -0.42, 5.57
# Position (x, y, z): 0.01, -0.42, 5.58
# Position (x, y, z): 0.01, -0.42, 5.58
# Position (x, y, z): 0.01, -0.43, 5.59
# Position (x, y, z): 0.01, -0.43, 5.60
# Position (x, y, z): 0.01, -0.43, 5.62
# Position (x, y, z): 0.02, -0.43, 5.63
# Position (x, y, z): 0.02, -0.43, 5.64
# Position (x, y, z): 0.03, -0.43, 5.66
# Position (x, y, z): 0.03, -0.43, 5.67
# Position (x, y, z): 0.03, -0.43, 5.69
# Position (x, y, z): 0.04, -0.43, 5.70
# Position (x, y, z): 0.04, -0.43, 5.71
# Position (x, y, z): 0.05, -0.44, 5.72
# Position (x, y, z): 0.05, -0.44, 5.73
# Position (x, y, z): 0.05, -0.45, 5.74
# Position (x, y, z): 0.05, -0.45, 5.75
# Position (x, y, z): 0.05, -0.45, 5.76
# Position (x, y, z): 0.05, -0.46, 5.76
# Position (x, y, z): 0.06, -0.46, 5.77
# Position (x, y, z): 0.05, -0.46, 5.78
# Position (x, y, z): 0.05, -0.46, 5.78
# Position (x, y, z): 0.05, -0.46, 5.79
# Position (x, y, z): 0.05, -0.47, 5.79
# Position (x, y, z): 0.05, -0.47, 5.80
# Position (x, y, z): 0.05, -0.47, 5.81
# Position (x, y, z): 0.05, -0.47, 5.81
# Position (x, y, z): 0.05, -0.47, 5.82
# Position (x, y, z): 0.05, -0.47, 5.82
# Position (x, y, z): 0.05, -0.47, 5.83
# Position (x, y, z): 0.04, -0.47, 5.83
# Position (x, y, z): 0.04, -0.46, 5.84
# Position (x, y, z): 0.04, -0.46, 5.84
# Position (x, y, z): 0.04, -0.46, 5.85
# Position (x, y, z): 0.04, -0.46, 5.85
# Position (x, y, z): 0.04, -0.46, 5.86
# Position (x, y, z): 0.04, -0.46, 5.87
# Position (x, y, z): 0.04, -0.46, 5.87
# Position (x, y, z): 0.04, -0.46, 5.87
# Position (x, y, z): 0.03, -0.46, 5.88
# Position (x, y, z): 0.03, -0.46, 5.88
# Position (x, y, z): 0.03, -0.46, 5.88
# Position (x, y, z): 0.03, -0.46, 5.89
# Position (x, y, z): 0.03, -0.46, 5.89
# Position (x, y, z): 0.02, -0.46, 5.89
# Position (x, y, z): 0.02, -0.45, 5.89
# Position (x, y, z): 0.02, -0.45, 5.89
# Position (x, y, z): 0.02, -0.45, 5.90
# Position (x, y, z): 0.01, -0.45, 5.90
# Position (x, y, z): 0.01, -0.45, 5.90
# Position (x, y, z): 0.01, -0.45, 5.91
# Position (x, y, z): 0.02, -0.45, 5.91
# Position (x, y, z): 0.02, -0.45, 5.92
# Position (x, y, z): 0.02, -0.46, 5.92
# Position (x, y, z): 0.02, -0.46, 5.92
# Position (x, y, z): 0.02, -0.47, 5.92
# Position (x, y, z): 0.01, -0.47, 5.92
# Position (x, y, z): 0.01, -0.47, 5.93
# Position (x, y, z): 0.01, -0.47, 5.93
# Position (x, y, z): 0.01, -0.47, 5.93
# Position (x, y, z): 0.01, -0.47, 5.94
# Position (x, y, z): 0.01, -0.48, 5.95
# Position (x, y, z): 0.01, -0.48, 5.95
# Position (x, y, z): 0.01, -0.48, 5.96
# Position (x, y, z): 0.01, -0.48, 5.96
# Position (x, y, z): 0.01, -0.49, 5.97
# Position (x, y, z): 0.01, -0.49, 5.97
# Position (x, y, z): 0.01, -0.49, 5.97
# Position (x, y, z): 0.01, -0.49, 5.98
# Position (x, y, z): 0.01, -0.49, 5.98
# Position (x, y, z): 0.02, -0.49, 5.99
# Position (x, y, z): 0.02, -0.49, 5.99
# Position (x, y, z): 0.02, -0.50, 6.00
# Position (x, y, z): 0.02, -0.50, 6.00
# Position (x, y, z): 0.02, -0.50, 6.00
# Position (x, y, z): 0.02, -0.51, 6.00
# Position (x, y, z): 0.02, -0.51, 6.00
# Position (x, y, z): 0.02, -0.51, 6.00
# Position (x, y, z): 0.02, -0.52, 6.01
# Position (x, y, z): 0.02, -0.52, 6.01
# Position (x, y, z): 0.02, -0.52, 6.02
# Position (x, y, z): 0.02, -0.52, 6.02
# Position (x, y, z): 0.03, -0.52, 6.02
# Position (x, y, z): 0.03, -0.51, 6.03
# Position (x, y, z): 0.03, -0.51, 6.03
# Position (x, y, z): 0.03, -0.51, 6.04
# Position (x, y, z): 0.03, -0.50, 6.04
# Position (x, y, z): 0.03, -0.50, 6.05
# Position (x, y, z): 0.04, -0.50, 6.05
# Position (x, y, z): 0.04, -0.50, 6.06
# Position (x, y, z): 0.04, -0.50, 6.06
# Position (x, y, z): 0.05, -0.50, 6.06
# Position (x, y, z): 0.05, -0.50, 6.06
# Position (x, y, z): 0.05, -0.50, 6.06
# Position (x, y, z): 0.05, -0.50, 6.07
# Position (x, y, z): 0.05, -0.50, 6.07
# Position (x, y, z): 0.06, -0.50, 6.07
# Position (x, y, z): 0.06, -0.50, 6.07
# Position (x, y, z): 0.06, -0.50, 6.07
# Position (x, y, z): 0.07, -0.50, 6.08
# Position (x, y, z): 0.07, -0.50, 6.08
# Position (x, y, z): 0.08, -0.50, 6.08
# Position (x, y, z): 0.08, -0.50, 6.09
# Position (x, y, z): 0.09, -0.50, 6.09
# Position (x, y, z): 0.09, -0.50, 6.09
# Position (x, y, z): 0.09, -0.50, 6.09
# Position (x, y, z): 0.10, -0.50, 6.09
# Position (x, y, z): 0.10, -0.50, 6.09
# Position (x, y, z): 0.10, -0.50, 6.09
# Position (x, y, z): 0.10, -0.49, 6.09
# Position (x, y, z): 0.10, -0.49, 6.10
# Position (x, y, z): 0.10, -0.49, 6.10
# Position (x, y, z): 0.11, -0.49, 6.10
# Position (x, y, z): 0.11, -0.49, 6.10
# Position (x, y, z): 0.11, -0.49, 6.10
# Position (x, y, z): 0.11, -0.49, 6.11
# Position (x, y, z): 0.11, -0.49, 6.11
# Position (x, y, z): 0.11, -0.49, 6.11
# Position (x, y, z): 0.11, -0.49, 6.11
# Position (x, y, z): 0.11, -0.49, 6.11
# Position (x, y, z): 0.11, -0.49, 6.11
# Position (x, y, z): 0.11, -0.48, 6.12
# Position (x, y, z): 0.11, -0.48, 6.12
# Position (x, y, z): 0.12, -0.48, 6.12
# Position (x, y, z): 0.12, -0.48, 6.12
# Position (x, y, z): 0.12, -0.48, 6.12
# Position (x, y, z): 0.12, -0.48, 6.13
# Position (x, y, z): 0.12, -0.48, 6.13
# Position (x, y, z): 0.13, -0.48, 6.13
# Position (x, y, z): 0.13, -0.48, 6.13
# Position (x, y, z): 0.13, -0.48, 6.13
# Position (x, y, z): 0.13, -0.48, 6.13
# Position (x, y, z): 0.13, -0.48, 6.13
# Position (x, y, z): 0.13, -0.48, 6.13
# Position (x, y, z): 0.13, -0.47, 6.13
# Position (x, y, z): 0.13, -0.47, 6.14
# Position (x, y, z): 0.13, -0.47, 6.14
# Position (x, y, z): 0.13, -0.47, 6.14
# Position (x, y, z): 0.13, -0.47, 6.14
# Position (x, y, z): 0.13, -0.47, 6.14
# Position (x, y, z): 0.13, -0.46, 6.14
# Position (x, y, z): 0.13, -0.47, 6.13
# Position (x, y, z): 0.14, -0.47, 6.13
# Position (x, y, z): 0.14, -0.47, 6.13
# Position (x, y, z): 0.13, -0.47, 6.13
# Position (x, y, z): 0.13, -0.46, 6.13
# Position (x, y, z): 0.13, -0.46, 6.13
# Position (x, y, z): 0.13, -0.47, 6.12
# Position (x, y, z): 0.13, -0.47, 6.12
# Position (x, y, z): 0.13, -0.47, 6.11
# Position (x, y, z): 0.14, -0.47, 6.12
# Position (x, y, z): 0.15, -0.47, 6.12
# Position (x, y, z): 0.15, -0.46, 6.12
# Position (x, y, z): 0.15, -0.46, 6.12
# Position (x, y, z): 0.15, -0.46, 6.12
# Position (x, y, z): 0.15, -0.46, 6.13
# Position (x, y, z): 0.15, -0.45, 6.13
# Position (x, y, z): 0.15, -0.45, 6.13
# Position (x, y, z): 0.15, -0.45, 6.13
# Position (x, y, z): 0.15, -0.45, 6.14
# Position (x, y, z): 0.15, -0.45, 6.14
# Position (x, y, z): 0.15, -0.45, 6.14
# Position (x, y, z): 0.14, -0.45, 6.14
# Position (x, y, z): 0.14, -0.45, 6.14
# Position (x, y, z): 0.14, -0.44, 6.14
# Position (x, y, z): 0.14, -0.44, 6.14
# Position (x, y, z): 0.14, -0.44, 6.15
# Position (x, y, z): 0.14, -0.44, 6.15
# Position (x, y, z): 0.14, -0.44, 6.15
# Position (x, y, z): 0.14, -0.44, 6.15
# Position (x, y, z): 0.14, -0.44, 6.15
# Position (x, y, z): 0.14, -0.44, 6.15
# Position (x, y, z): 0.14, -0.44, 6.15
# Position (x, y, z): 0.14, -0.44, 6.15
# Position (x, y, z): 0.14, -0.44, 6.15
# Position (x, y, z): 0.14, -0.44, 6.15
# Position (x, y, z): 0.14, -0.43, 6.15
# Position (x, y, z): 0.14, -0.43, 6.15
# Position (x, y, z): 0.14, -0.43, 6.15
# Position (x, y, z): 0.14, -0.43, 6.15
# Position (x, y, z): 0.13, -0.43, 6.15
# Position (x, y, z): 0.13, -0.43, 6.15
# Position (x, y, z): 0.13, -0.43, 6.15
# Position (x, y, z): 0.13, -0.43, 6.15
# Position (x, y, z): 0.14, -0.43, 6.15
# Position (x, y, z): 0.14, -0.43, 6.15
# Position (x, y, z): 0.14, -0.43, 6.15
# Position (x, y, z): 0.14, -0.42, 6.15
# Position (x, y, z): 0.14, -0.42, 6.15
# Position (x, y, z): 0.14, -0.42, 6.15
# Position (x, y, z): 0.14, -0.42, 6.15
# Position (x, y, z): 0.14, -0.42, 6.16
# Position (x, y, z): 0.14, -0.41, 6.16
# Position (x, y, z): 0.14, -0.41, 6.16
# Position (x, y, z): 0.13, -0.41, 6.16
# Position (x, y, z): 0.13, -0.41, 6.16
# Position (x, y, z): 0.13, -0.41, 6.16
# Position (x, y, z): 0.13, -0.41, 6.16
# Position (x, y, z): 0.13, -0.41, 6.16
# Position (x, y, z): 0.13, -0.40, 6.16
# Position (x, y, z): 0.13, -0.40, 6.16
# Position (x, y, z): 0.13, -0.40, 6.16
# Position (x, y, z): 0.13, -0.40, 6.16
# Position (x, y, z): 0.13, -0.40, 6.16
# Position (x, y, z): 0.13, -0.40, 6.16
# Position (x, y, z): 0.13, -0.40, 6.16
# Position (x, y, z): 0.13, -0.40, 6.16
# Position (x, y, z): 0.13, -0.40, 6.16
# Position (x, y, z): 0.13, -0.40, 6.16
# Position (x, y, z): 0.13, -0.40, 6.16
# Position (x, y, z): 0.13, -0.40, 6.17
# Position (x, y, z): 0.13, -0.40, 6.17
# Position (x, y, z): 0.13, -0.40, 6.17
# Position (x, y, z): 0.13, -0.40, 6.17
# Position (x, y, z): 0.13, -0.40, 6.17
# Position (x, y, z): 0.13, -0.40, 6.16
# Position (x, y, z): 0.12, -0.40, 6.16
# Position (x, y, z): 0.12, -0.40, 6.16
# Position (x, y, z): 0.12, -0.40, 6.16
# Position (x, y, z): 0.12, -0.40, 6.16
# Position (x, y, z): 0.12, -0.40, 6.16
# Position (x, y, z): 0.12, -0.40, 6.17
# Position (x, y, z): 0.12, -0.40, 6.17
# Position (x, y, z): 0.12, -0.40, 6.17
# Position (x, y, z): 0.12, -0.40, 6.17
# Position (x, y, z): 0.12, -0.40, 6.17
# Position (x, y, z): 0.12, -0.40, 6.17
# Position (x, y, z): 0.12, -0.40, 6.17
# Position (x, y, z): 0.12, -0.40, 6.17
# Position (x, y, z): 0.12, -0.40, 6.17
# Position (x, y, z): 0.12, -0.40, 6.17
# Position (x, y, z): 0.11, -0.39, 6.17
# Position (x, y, z): 0.11, -0.39, 6.17
# Position (x, y, z): 0.11, -0.39, 6.17
# Position (x, y, z): 0.11, -0.39, 6.17
# Position (x, y, z): 0.11, -0.39, 6.17
# Position (x, y, z): 0.11, -0.38, 6.17
# Position (x, y, z): 0.11, -0.38, 6.17
# Position (x, y, z): 0.11, -0.38, 6.17
# Position (x, y, z): 0.11, -0.38, 6.17
# Position (x, y, z): 0.11, -0.37, 6.17
# Position (x, y, z): 0.12, -0.37, 6.17
# Position (x, y, z): 0.12, -0.37, 6.17
# Position (x, y, z): 0.11, -0.37, 6.17
# Position (x, y, z): 0.11, -0.37, 6.16
# Position (x, y, z): 0.11, -0.37, 6.16
# Position (x, y, z): 0.11, -0.37, 6.16
# Position (x, y, z): 0.11, -0.37, 6.16
# Position (x, y, z): 0.11, -0.37, 6.16
# Position (x, y, z): 0.11, -0.37, 6.16
# Position (x, y, z): 0.11, -0.37, 6.16
# Position (x, y, z): 0.11, -0.37, 6.17
# Position (x, y, z): 0.11, -0.37, 6.17
# Position (x, y, z): 0.11, -0.37, 6.17
# Position (x, y, z): 0.12, -0.37, 6.17
# Position (x, y, z): 0.12, -0.36, 6.17
# Position (x, y, z): 0.12, -0.36, 6.17
# Position (x, y, z): 0.12, -0.36, 6.17
# Position (x, y, z): 0.12, -0.36, 6.17
# Position (x, y, z): 0.12, -0.36, 6.17
# Position (x, y, z): 0.12, -0.36, 6.17
# Position (x, y, z): 0.12, -0.36, 6.17
# Position (x, y, z): 0.12, -0.36, 6.17
# Position (x, y, z): 0.12, -0.36, 6.17
# Position (x, y, z): 0.12, -0.36, 6.17
# Position (x, y, z): 0.12, -0.36, 6.17
# Position (x, y, z): 0.12, -0.36, 6.17
# Position (x, y, z): 0.13, -0.36, 6.17
# Position (x, y, z): 0.13, -0.36, 6.17
# Position (x, y, z): 0.13, -0.36, 6.17
# Position (x, y, z): 0.13, -0.36, 6.18
# Position (x, y, z): 0.13, -0.36, 6.18
# Position (x, y, z): 0.13, -0.37, 6.18
# Position (x, y, z): 0.13, -0.37, 6.18
# Position (x, y, z): 0.13, -0.37, 6.18
# Position (x, y, z): 0.13, -0.37, 6.18
# Position (x, y, z): 0.14, -0.37, 6.17
# Position (x, y, z): 0.14, -0.36, 6.17
# Position (x, y, z): 0.14, -0.36, 6.17
# Position (x, y, z): 0.14, -0.36, 6.17
# Position (x, y, z): 0.14, -0.36, 6.17
# Position (x, y, z): 0.14, -0.36, 6.18
# Position (x, y, z): 0.14, -0.37, 6.18
# Position (x, y, z): 0.15, -0.37, 6.18
# Position (x, y, z): 0.15, -0.37, 6.18
# Position (x, y, z): 0.15, -0.37, 6.18
# Position (x, y, z): 0.15, -0.36, 6.18
# Position (x, y, z): 0.15, -0.36, 6.18
# Position (x, y, z): 0.15, -0.36, 6.18
# Position (x, y, z): 0.15, -0.36, 6.18
# Position (x, y, z): 0.15, -0.36, 6.18
# Position (x, y, z): 0.15, -0.36, 6.18
# Position (x, y, z): 0.15, -0.36, 6.18
# Position (x, y, z): 0.15, -0.36, 6.18
# Position (x, y, z): 0.16, -0.36, 6.18
# Position (x, y, z): 0.16, -0.36, 6.18
# Position (x, y, z): 0.16, -0.36, 6.18
# Position (x, y, z): 0.16, -0.36, 6.18
# Position (x, y, z): 0.16, -0.36, 6.18
# Position (x, y, z): 0.16, -0.36, 6.18
# Position (x, y, z): 0.16, -0.36, 6.18
# Position (x, y, z): 0.16, -0.36, 6.18
# Position (x, y, z): 0.16, -0.36, 6.18
# Position (x, y, z): 0.16, -0.36, 6.18
# Position (x, y, z): 0.16, -0.35, 6.18
# Position (x, y, z): 0.16, -0.35, 6.18
# Position (x, y, z): 0.16, -0.35, 6.18
# Position (x, y, z): 0.16, -0.35, 6.18
# Position (x, y, z): 0.16, -0.35, 6.18
# Position (x, y, z): 0.16, -0.35, 6.18
# Position (x, y, z): 0.16, -0.35, 6.18
# Position (x, y, z): 0.16, -0.35, 6.18
# Position (x, y, z): 0.16, -0.35, 6.18
# Position (x, y, z): 0.16, -0.36, 6.18
# Position (x, y, z): 0.16, -0.36, 6.18
# Position (x, y, z): 0.16, -0.36, 6.18
# Position (x, y, z): 0.16, -0.35, 6.18
# Position (x, y, z): 0.16, -0.35, 6.18
# Position (x, y, z): 0.16, -0.35, 6.18
# Position (x, y, z): 0.16, -0.35, 6.18
# Position (x, y, z): 0.16, -0.35, 6.18
# Position (x, y, z): 0.16, -0.35, 6.18
# Position (x, y, z): 0.16, -0.35, 6.18
# Position (x, y, z): 0.16, -0.35, 6.18
# Position (x, y, z): 0.16, -0.35, 6.18
# Position (x, y, z): 0.16, -0.35, 6.18
# Position (x, y, z): 0.16, -0.35, 6.18
# Position (x, y, z): 0.16, -0.35, 6.18
# Position (x, y, z): 0.16, -0.35, 6.18
# Position (x, y, z): 0.16, -0.35, 6.18
# Position (x, y, z): 0.16, -0.35, 6.18
# Position (x, y, z): 0.16, -0.35, 6.18
# Position (x, y, z): 0.16, -0.35, 6.18
# Position (x, y, z): 0.16, -0.35, 6.18
# Position (x, y, z): 0.16, -0.35, 6.18
# Position (x, y, z): 0.16, -0.35, 6.18
# Position (x, y, z): 0.16, -0.35, 6.18
# Position (x, y, z): 0.16, -0.35, 6.18
# Position (x, y, z): 0.16, -0.35, 6.18
# Position (x, y, z): 0.16, -0.35, 6.18
# Position (x, y, z): 0.16, -0.35, 6.18
# Position (x, y, z): 0.16, -0.35, 6.18
# Position (x, y, z): 0.16, -0.35, 6.18
# Position (x, y, z): 0.16, -0.35, 6.18
# Position (x, y, z): 0.16, -0.34, 6.18
# Position (x, y, z): 0.16, -0.34, 6.18
# Position (x, y, z): 0.16, -0.34, 6.18
# Position (x, y, z): 0.16, -0.34, 6.18
# Position (x, y, z): 0.16, -0.34, 6.18
# Position (x, y, z): 0.16, -0.34, 6.18
# Position (x, y, z): 0.16, -0.34, 6.18
# Position (x, y, z): 0.16, -0.34, 6.18
# Position (x, y, z): 0.16, -0.34, 6.18
# Position (x, y, z): 0.16, -0.34, 6.18
# Position (x, y, z): 0.16, -0.34, 6.18
# Position (x, y, z): 0.16, -0.34, 6.18
# Position (x, y, z): 0.16, -0.34, 6.18
# Position (x, y, z): 0.16, -0.34, 6.18
# Position (x, y, z): 0.16, -0.34, 6.18
# Position (x, y, z): 0.16, -0.34, 6.18
# Position (x, y, z): 0.16, -0.34, 6.18
# Position (x, y, z): 0.15, -0.34, 6.18
# Position (x, y, z): 0.15, -0.34, 6.18
# Position (x, y, z): 0.15, -0.34, 6.18
# Position (x, y, z): 0.15, -0.34, 6.18
# Position (x, y, z): 0.15, -0.34, 6.18
# Position (x, y, z): 0.15, -0.35, 6.18
# Position (x, y, z): 0.15, -0.35, 6.18
# Position (x, y, z): 0.15, -0.35, 6.18
# Position (x, y, z): 0.15, -0.35, 6.18
# Position (x, y, z): 0.15, -0.35, 6.18
# Position (x, y, z): 0.15, -0.35, 6.18
# Position (x, y, z): 0.15, -0.35, 6.18
# Position (x, y, z): 0.15, -0.35, 6.18
# Position (x, y, z): 0.15, -0.35, 6.18
# Position (x, y, z): 0.15, -0.34, 6.18
# Position (x, y, z): 0.15, -0.34, 6.18
# Position (x, y, z): 0.15, -0.34, 6.18
# Position (x, y, z): 0.15, -0.34, 6.18
# Position (x, y, z): 0.15, -0.34, 6.18
# Position (x, y, z): 0.15, -0.34, 6.18
# Position (x, y, z): 0.15, -0.34, 6.18
# Position (x, y, z): 0.15, -0.34, 6.18
# Position (x, y, z): 0.14, -0.34, 6.18
# Position (x, y, z): 0.14, -0.34, 6.18
# Position (x, y, z): 0.14, -0.34, 6.18
# Position (x, y, z): 0.14, -0.34, 6.18
# Position (x, y, z): 0.14, -0.34, 6.18
# Position (x, y, z): 0.14, -0.34, 6.18
# Position (x, y, z): 0.14, -0.34, 6.18
# Position (x, y, z): 0.14, -0.34, 6.18
# Position (x, y, z): 0.14, -0.34, 6.18
# Position (x, y, z): 0.14, -0.34, 6.18
# Position (x, y, z): 0.14, -0.34, 6.18
# Position (x, y, z): 0.14, -0.34, 6.18
# Position (x, y, z): 0.14, -0.34, 6.18
# Position (x, y, z): 0.14, -0.34, 6.18
# Position (x, y, z): 0.14, -0.34, 6.18
# Position (x, y, z): 0.14, -0.34, 6.18
# Position (x, y, z): 0.14, -0.34, 6.18
# Position (x, y, z): 0.14, -0.34, 6.18
# Position (x, y, z): 0.13, -0.34, 6.18
# Position (x, y, z): 0.13, -0.34, 6.18
# Position (x, y, z): 0.13, -0.34, 6.18
# Position (x, y, z): 0.13, -0.34, 6.18
# Position (x, y, z): 0.13, -0.34, 6.18
# Position (x, y, z): 0.13, -0.34, 6.18
# Position (x, y, z): 0.13, -0.34, 6.18
# Position (x, y, z): 0.13, -0.34, 6.18
# Position (x, y, z): 0.13, -0.34, 6.18
# Position (x, y, z): 0.13, -0.34, 6.18
# Position (x, y, z): 0.13, -0.34, 6.18
# Position (x, y, z): 0.13, -0.34, 6.18
# Position (x, y, z): 0.13, -0.34, 6.18
# Position (x, y, z): 0.13, -0.34, 6.18
# Position (x, y, z): 0.13, -0.34, 6.18
# Position (x, y, z): 0.13, -0.34, 6.18
# Position (x, y, z): 0.13, -0.34, 6.18
# Position (x, y, z): 0.13, -0.34, 6.18
# Position (x, y, z): 0.12, -0.34, 6.18
# Position (x, y, z): 0.12, -0.34, 6.18
# Position (x, y, z): 0.12, -0.34, 6.18
# Position (x, y, z): 0.12, -0.34, 6.18
# Position (x, y, z): 0.12, -0.35, 6.18
# Position (x, y, z): 0.12, -0.35, 6.18
# Position (x, y, z): 0.12, -0.35, 6.18
# Position (x, y, z): 0.12, -0.35, 6.18
# Position (x, y, z): 0.12, -0.35, 6.18
# Position (x, y, z): 0.12, -0.35, 6.18
# Position (x, y, z): 0.12, -0.35, 6.18
# Position (x, y, z): 0.12, -0.35, 6.18
# Position (x, y, z): 0.12, -0.35, 6.18
# Position (x, y, z): 0.12, -0.35, 6.18
# Position (x, y, z): 0.12, -0.35, 6.18
# Position (x, y, z): 0.12, -0.35, 6.18
# Position (x, y, z): 0.12, -0.35, 6.18
# Position (x, y, z): 0.11, -0.35, 6.18
# Position (x, y, z): 0.11, -0.35, 6.18
# Position (x, y, z): 0.11, -0.35, 6.18
# Position (x, y, z): 0.11, -0.35, 6.18
# Position (x, y, z): 0.12, -0.35, 6.18
# Position (x, y, z): 0.12, -0.35, 6.18
# Position (x, y, z): 0.12, -0.35, 6.18
# Position (x, y, z): 0.12, -0.35, 6.18
# Position (x, y, z): 0.12, -0.35, 6.18
# Position (x, y, z): 0.11, -0.35, 6.18
# Position (x, y, z): 0.11, -0.35, 6.18
# Position (x, y, z): 0.11, -0.35, 6.18
# Position (x, y, z): 0.11, -0.35, 6.18
# Position (x, y, z): 0.11, -0.35, 6.18
# Position (x, y, z): 0.11, -0.35, 6.18
# Position (x, y, z): 0.11, -0.35, 6.18
# Position (x, y, z): 0.11, -0.35, 6.18
# Position (x, y, z): 0.11, -0.36, 6.18
# Position (x, y, z): 0.12, -0.36, 6.18
# Position (x, y, z): 0.12, -0.36, 6.18
# Position (x, y, z): 0.12, -0.36, 6.18
# Position (x, y, z): 0.11, -0.36, 6.18
# Position (x, y, z): 0.11, -0.36, 6.18
# Position (x, y, z): 0.11, -0.36, 6.18
# Position (x, y, z): 0.11, -0.36, 6.18
# Position (x, y, z): 0.11, -0.36, 6.18
# Position (x, y, z): 0.11, -0.36, 6.18
# Position (x, y, z): 0.11, -0.36, 6.18
# Position (x, y, z): 0.11, -0.36, 6.18
# Position (x, y, z): 0.11, -0.36, 6.18
# Position (x, y, z): 0.11, -0.36, 6.18
# Position (x, y, z): 0.11, -0.36, 6.18
# Position (x, y, z): 0.11, -0.36, 6.18
# Position (x, y, z): 0.11, -0.36, 6.18
# Position (x, y, z): 0.11, -0.36, 6.18
# Position (x, y, z): 0.11, -0.36, 6.18
# Position (x, y, z): 0.11, -0.36, 6.18
# Position (x, y, z): 0.11, -0.36, 6.18
# Position (x, y, z): 0.11, -0.36, 6.18
# Position (x, y, z): 0.11, -0.36, 6.18
# Position (x, y, z): 0.11, -0.36, 6.18
# Position (x, y, z): 0.11, -0.36, 6.18
# Position (x, y, z): 0.11, -0.36, 6.18
# Position (x, y, z): 0.11, -0.36, 6.18
# Position (x, y, z): 0.11, -0.36, 6.18
# Position (x, y, z): 0.11, -0.36, 6.18
# Position (x, y, z): 0.11, -0.36, 6.18
# Position (x, y, z): 0.11, -0.37, 6.18
# Position (x, y, z): 0.11, -0.37, 6.18
# Position (x, y, z): 0.11, -0.37, 6.18
# Position (x, y, z): 0.11, -0.37, 6.18
# Position (x, y, z): 0.11, -0.37, 6.18
# Position (x, y, z): 0.11, -0.37, 6.18
# Position (x, y, z): 0.11, -0.37, 6.18
# Position (x, y, z): 0.11, -0.37, 6.18
# Position (x, y, z): 0.11, -0.37, 6.18
# Position (x, y, z): 0.11, -0.37, 6.18
# Position (x, y, z): 0.10, -0.37, 6.18
# Position (x, y, z): 0.10, -0.37, 6.18
# Position (x, y, z): 0.10, -0.37, 6.18
# Position (x, y, z): 0.10, -0.37, 6.18
# Position (x, y, z): 0.10, -0.37, 6.18
# Position (x, y, z): 0.10, -0.37, 6.18
# Position (x, y, z): 0.10, -0.37, 6.18
# Position (x, y, z): 0.10, -0.37, 6.18
# Position (x, y, z): 0.10, -0.37, 6.18
# Position (x, y, z): 0.10, -0.37, 6.18
# Position (x, y, z): 0.10, -0.37, 6.18
# Position (x, y, z): 0.10, -0.37, 6.18
# Position (x, y, z): 0.10, -0.37, 6.18
# Position (x, y, z): 0.10, -0.37, 6.18
# Position (x, y, z): 0.10, -0.37, 6.18
# Position (x, y, z): 0.10, -0.37, 6.18
# Position (x, y, z): 0.10, -0.37, 6.18
# Position (x, y, z): 0.10, -0.37, 6.18
# Position (x, y, z): 0.10, -0.37, 6.18
# Position (x, y, z): 0.10, -0.37, 6.18
# Position (x, y, z): 0.10, -0.37, 6.18
# Position (x, y, z): 0.10, -0.37, 6.18
# Position (x, y, z): 0.10, -0.37, 6.18
# Position (x, y, z): 0.10, -0.37, 6.18
# Position (x, y, z): 0.10, -0.37, 6.18
# Position (x, y, z): 0.10, -0.37, 6.18
# Position (x, y, z): 0.10, -0.37, 6.18
# Position (x, y, z): 0.10, -0.37, 6.18
# Position (x, y, z): 0.10, -0.37, 6.18
# Position (x, y, z): 0.10, -0.37, 6.18
# Position (x, y, z): 0.10, -0.37, 6.18
# Position (x, y, z): 0.10, -0.37, 6.18
# Position (x, y, z): 0.10, -0.37, 6.18
# Position (x, y, z): 0.10, -0.37, 6.18
# Position (x, y, z): 0.10, -0.37, 6.18
# Position (x, y, z): 0.10, -0.37, 6.18
# Position (x, y, z): 0.10, -0.37, 6.18
# Position (x, y, z): 0.10, -0.37, 6.18
# Position (x, y, z): 0.10, -0.37, 6.18
# Position (x, y, z): 0.10, -0.37, 6.17
# Position (x, y, z): 0.10, -0.37, 6.17
# Position (x, y, z): 0.10, -0.37, 6.17
# Position (x, y, z): 0.10, -0.37, 6.17
# Position (x, y, z): 0.10, -0.37, 6.18
# Position (x, y, z): 0.10, -0.38, 6.18
# Position (x, y, z): 0.10, -0.38, 6.18
# Position (x, y, z): 0.10, -0.38, 6.18
# Position (x, y, z): 0.10, -0.38, 6.18
# Position (x, y, z): 0.10, -0.38, 6.18
# Position (x, y, z): 0.10, -0.38, 6.18
# Position (x, y, z): 0.10, -0.38, 6.18
# Position (x, y, z): 0.10, -0.38, 6.18
# Position (x, y, z): 0.10, -0.38, 6.18
# Position (x, y, z): 0.10, -0.38, 6.18
# Position (x, y, z): 0.09, -0.38, 6.18
# Position (x, y, z): 0.09, -0.38, 6.18
# Position (x, y, z): 0.09, -0.38, 6.18
# Position (x, y, z): 0.09, -0.38, 6.18
# Position (x, y, z): 0.09, -0.38, 6.18
# Position (x, y, z): 0.09, -0.38, 6.18
# Position (x, y, z): 0.09, -0.38, 6.18
# Position (x, y, z): 0.09, -0.38, 6.18
# Position (x, y, z): 0.09, -0.38, 6.17
# Position (x, y, z): 0.09, -0.38, 6.17
# Position (x, y, z): 0.09, -0.38, 6.17
# Position (x, y, z): 0.09, -0.38, 6.17
# Position (x, y, z): 0.09, -0.38, 6.17
# Position (x, y, z): 0.09, -0.38, 6.17
# Position (x, y, z): 0.09, -0.38, 6.17
# Position (x, y, z): 0.09, -0.38, 6.17
# Position (x, y, z): 0.09, -0.38, 6.17
# Position (x, y, z): 0.09, -0.38, 6.17
# Position (x, y, z): 0.09, -0.38, 6.17
# Position (x, y, z): 0.09, -0.38, 6.17
# Position (x, y, z): 0.09, -0.38, 6.17
# Position (x, y, z): 0.09, -0.38, 6.17
# Position (x, y, z): 0.09, -0.38, 6.17
# Position (x, y, z): 0.09, -0.38, 6.17
# Position (x, y, z): 0.09, -0.38, 6.17
# Position (x, y, z): 0.09, -0.38, 6.17
# Position (x, y, z): 0.09, -0.38, 6.17
# Position (x, y, z): 0.09, -0.38, 6.17
# Position (x, y, z): 0.09, -0.38, 6.17
# Position (x, y, z): 0.09, -0.38, 6.17
# Position (x, y, z): 0.09, -0.38, 6.17
# Position (x, y, z): 0.08, -0.38, 6.17
# Position (x, y, z): 0.08, -0.38, 6.18
# Position (x, y, z): 0.08, -0.38, 6.18
# Position (x, y, z): 0.08, -0.38, 6.18
# Position (x, y, z): 0.09, -0.38, 6.18
# Position (x, y, z): 0.09, -0.38, 6.18
# Position (x, y, z): 0.09, -0.38, 6.18
# Position (x, y, z): 0.09, -0.38, 6.18
# Position (x, y, z): 0.09, -0.38, 6.18
# Position (x, y, z): 0.09, -0.38, 6.18
# Position (x, y, z): 0.08, -0.38, 6.18
# Position (x, y, z): 0.08, -0.38, 6.18
# Position (x, y, z): 0.09, -0.38, 6.18
# Position (x, y, z): 0.09, -0.38, 6.18
# Position (x, y, z): 0.09, -0.38, 6.18
# Position (x, y, z): 0.09, -0.38, 6.18
# Position (x, y, z): 0.09, -0.38, 6.18
# Position (x, y, z): 0.09, -0.38, 6.18
# Position (x, y, z): 0.09, -0.38, 6.18
# Position (x, y, z): 0.09, -0.38, 6.18
# Position (x, y, z): 0.09, -0.38, 6.18
# Position (x, y, z): 0.09, -0.38, 6.18
# Position (x, y, z): 0.09, -0.38, 6.18
# Position (x, y, z): 0.09, -0.38, 6.18
# Position (x, y, z): 0.09, -0.38, 6.18
# Position (x, y, z): 0.09, -0.38, 6.18
# Position (x, y, z): 0.09, -0.38, 6.18
# Position (x, y, z): 0.09, -0.38, 6.18
# Position (x, y, z): 0.09, -0.38, 6.18
# Position (x, y, z): 0.09, -0.39, 6.18
# Position (x, y, z): 0.09, -0.38, 6.18
# Position (x, y, z): 0.09, -0.38, 6.18
# Position (x, y, z): 0.09, -0.39, 6.18
# Position (x, y, z): 0.09, -0.39, 6.18
# Position (x, y, z): 0.09, -0.39, 6.18
# Position (x, y, z): 0.09, -0.39, 6.18
# Position (x, y, z): 0.09, -0.39, 6.17
# Position (x, y, z): 0.09, -0.39, 6.17
# Position (x, y, z): 0.09, -0.39, 6.17
# Position (x, y, z): 0.08, -0.39, 6.17
# Position (x, y, z): 0.08, -0.39, 6.17
# Position (x, y, z): 0.08, -0.39, 6.17
# Position (x, y, z): 0.08, -0.38, 6.17
# Position (x, y, z): 0.08, -0.38, 6.17
# Position (x, y, z): 0.08, -0.38, 6.17
# Position (x, y, z): 0.08, -0.38, 6.17
# Position (x, y, z): 0.08, -0.38, 6.17
# Position (x, y, z): 0.08, -0.39, 6.17
# Position (x, y, z): 0.08, -0.39, 6.18
# Position (x, y, z): 0.08, -0.39, 6.18
# Position (x, y, z): 0.08, -0.39, 6.18
# Position (x, y, z): 0.08, -0.39, 6.18
# Position (x, y, z): 0.08, -0.39, 6.18
# Position (x, y, z): 0.08, -0.39, 6.18
# Position (x, y, z): 0.08, -0.39, 6.18
# Position (x, y, z): 0.08, -0.39, 6.18
# Position (x, y, z): 0.08, -0.39, 6.18
# Position (x, y, z): 0.08, -0.39, 6.18
# Position (x, y, z): 0.08, -0.39, 6.18
# Position (x, y, z): 0.08, -0.39, 6.18
# Position (x, y, z): 0.08, -0.39, 6.18
# Position (x, y, z): 0.08, -0.39, 6.18
# Position (x, y, z): 0.08, -0.39, 6.18
# Position (x, y, z): 0.08, -0.39, 6.18
# Position (x, y, z): 0.08, -0.39, 6.18
# Position (x, y, z): 0.08, -0.39, 6.18
# Position (x, y, z): 0.08, -0.39, 6.18
# Position (x, y, z): 0.08, -0.39, 6.18
# Position (x, y, z): 0.08, -0.39, 6.17
# Position (x, y, z): 0.08, -0.39, 6.17
# Position (x, y, z): 0.08, -0.39, 6.17
# Position (x, y, z): 0.08, -0.39, 6.17
# Position (x, y, z): 0.08, -0.39, 6.17
# Position (x, y, z): 0.08, -0.39, 6.17
# Position (x, y, z): 0.08, -0.39, 6.17
# Position (x, y, z): 0.08, -0.39, 6.17
# Position (x, y, z): 0.08, -0.39, 6.17
# Position (x, y, z): 0.08, -0.39, 6.17
# Position (x, y, z): 0.08, -0.39, 6.17
# Position (x, y, z): 0.08, -0.39, 6.17
# Position (x, y, z): 0.08, -0.39, 6.17
# Position (x, y, z): 0.08, -0.39, 6.17
# Position (x, y, z): 0.08, -0.39, 6.17
# Position (x, y, z): 0.08, -0.40, 6.17
# Position (x, y, z): 0.08, -0.40, 6.17
# Position (x, y, z): 0.08, -0.40, 6.17
# Position (x, y, z): 0.08, -0.40, 6.17
# Position (x, y, z): 0.08, -0.40, 6.17
# Position (x, y, z): 0.08, -0.40, 6.17
# Position (x, y, z): 0.08, -0.40, 6.17
# Position (x, y, z): 0.08, -0.40, 6.17
# Position (x, y, z): 0.08, -0.40, 6.17
# Position (x, y, z): 0.08, -0.40, 6.17
# Position (x, y, z): 0.08, -0.40, 6.17
# Position (x, y, z): 0.08, -0.40, 6.18
# Position (x, y, z): 0.08, -0.41, 6.18
# Position (x, y, z): 0.08, -0.41, 6.18
# Position (x, y, z): 0.07, -0.41, 6.18
# Position (x, y, z): 0.07, -0.42, 6.18
# Position (x, y, z): 0.07, -0.42, 6.19
# Position (x, y, z): 0.07, -0.42, 6.19
# Position (x, y, z): 0.07, -0.43, 6.19
# Position (x, y, z): 0.08, -0.43, 6.19
# Position (x, y, z): 0.08, -0.43, 6.19
# Position (x, y, z): 0.08, -0.43, 6.19
# Position (x, y, z): 0.08, -0.43, 6.18
# Position (x, y, z): 0.08, -0.43, 6.18
# Position (x, y, z): 0.08, -0.43, 6.18
# Position (x, y, z): 0.08, -0.43, 6.17
# Position (x, y, z): 0.08, -0.43, 6.17
# Position (x, y, z): 0.08, -0.43, 6.17
# Position (x, y, z): 0.08, -0.44, 6.17
# Position (x, y, z): 0.08, -0.44, 6.17
# Position (x, y, z): 0.08, -0.44, 6.17
# Position (x, y, z): 0.08, -0.45, 6.17
# Position (x, y, z): 0.08, -0.45, 6.16
# Position (x, y, z): 0.09, -0.45, 6.16
# Position (x, y, z): 0.09, -0.45, 6.16
# Position (x, y, z): 0.09, -0.45, 6.16
# Position (x, y, z): 0.09, -0.45, 6.16
# Position (x, y, z): 0.09, -0.45, 6.16
# Position (x, y, z): 0.09, -0.45, 6.16
# Position (x, y, z): 0.09, -0.45, 6.16
# Position (x, y, z): 0.09, -0.46, 6.16
# Position (x, y, z): 0.09, -0.46, 6.16
# Position (x, y, z): 0.09, -0.46, 6.16
# Position (x, y, z): 0.09, -0.46, 6.16
# Position (x, y, z): 0.09, -0.46, 6.16
# Position (x, y, z): 0.09, -0.46, 6.16
# Position (x, y, z): 0.09, -0.46, 6.16
# Position (x, y, z): 0.09, -0.46, 6.16
# Position (x, y, z): 0.09, -0.47, 6.16
# Position (x, y, z): 0.09, -0.47, 6.16
# Position (x, y, z): 0.09, -0.47, 6.16
# Position (x, y, z): 0.09, -0.47, 6.16
# Position (x, y, z): 0.09, -0.47, 6.16
# Position (x, y, z): 0.09, -0.47, 6.16
# Position (x, y, z): 0.09, -0.47, 6.16
# Position (x, y, z): 0.09, -0.47, 6.16
# Position (x, y, z): 0.09, -0.47, 6.16
# Position (x, y, z): 0.09, -0.47, 6.16
# Position (x, y, z): 0.09, -0.47, 6.15
# Position (x, y, z): 0.09, -0.47, 6.15
# Position (x, y, z): 0.09, -0.47, 6.15
# Position (x, y, z): 0.09, -0.47, 6.15
# Position (x, y, z): 0.09, -0.47, 6.15
# Position (x, y, z): 0.09, -0.47, 6.15
# Position (x, y, z): 0.09, -0.47, 6.15
# Position (x, y, z): 0.09, -0.48, 6.15
# Position (x, y, z): 0.09, -0.48, 6.16
# Position (x, y, z): 0.09, -0.48, 6.16
# Position (x, y, z): 0.08, -0.48, 6.16
# Position (x, y, z): 0.08, -0.48, 6.16
# Position (x, y, z): 0.08, -0.48, 6.16
# Position (x, y, z): 0.08, -0.48, 6.17
# Position (x, y, z): 0.08, -0.48, 6.17
# Position (x, y, z): 0.08, -0.48, 6.17
# Position (x, y, z): 0.08, -0.48, 6.17
# Position (x, y, z): 0.08, -0.47, 6.17
# Position (x, y, z): 0.09, -0.47, 6.17
# Position (x, y, z): 0.09, -0.47, 6.17
# Position (x, y, z): 0.09, -0.47, 6.16
# Position (x, y, z): 0.09, -0.46, 6.16
# Position (x, y, z): 0.10, -0.47, 6.16
# Position (x, y, z): 0.11, -0.47, 6.15
# Position (x, y, z): 0.11, -0.47, 6.15
# Position (x, y, z): 0.12, -0.47, 6.15
# Position (x, y, z): 0.13, -0.47, 6.15
# Position (x, y, z): 0.13, -0.47, 6.15
# Position (x, y, z): 0.14, -0.47, 6.15
# Position (x, y, z): 0.14, -0.47, 6.15
# Position (x, y, z): 0.15, -0.47, 6.15
# Position (x, y, z): 0.15, -0.47, 6.16
# Position (x, y, z): 0.16, -0.47, 6.16
# Position (x, y, z): 0.16, -0.47, 6.16
# Position (x, y, z): 0.16, -0.47, 6.16
# Position (x, y, z): 0.16, -0.47, 6.17
# Position (x, y, z): 0.17, -0.47, 6.17
# Position (x, y, z): 0.17, -0.47, 6.17
# Position (x, y, z): 0.17, -0.47, 6.17
# Position (x, y, z): 0.17, -0.47, 6.17
# Position (x, y, z): 0.17, -0.46, 6.17
# Position (x, y, z): 0.17, -0.46, 6.17
# Position (x, y, z): 0.18, -0.46, 6.17
# Position (x, y, z): 0.18, -0.45, 6.17
# Position (x, y, z): 0.18, -0.45, 6.17
# Position (x, y, z): 0.19, -0.45, 6.17
# Position (x, y, z): 0.19, -0.45, 6.17
# Position (x, y, z): 0.20, -0.45, 6.17
# Position (x, y, z): 0.20, -0.45, 6.17
# Position (x, y, z): 0.20, -0.45, 6.17
# Position (x, y, z): 0.21, -0.45, 6.17
# Position (x, y, z): 0.21, -0.45, 6.17
# Position (x, y, z): 0.21, -0.45, 6.17
# Position (x, y, z): 0.21, -0.45, 6.17
# Position (x, y, z): 0.21, -0.45, 6.17
# Position (x, y, z): 0.21, -0.45, 6.17
# Position (x, y, z): 0.21, -0.45, 6.16
# Position (x, y, z): 0.21, -0.44, 6.16
# Position (x, y, z): 0.21, -0.44, 6.16
# Position (x, y, z): 0.22, -0.44, 6.16
# Position (x, y, z): 0.22, -0.44, 6.16
# Position (x, y, z): 0.22, -0.44, 6.16
# Position (x, y, z): 0.22, -0.45, 6.16
# Position (x, y, z): 0.22, -0.45, 6.16
# Position (x, y, z): 0.22, -0.45, 6.16
# Position (x, y, z): 0.22, -0.45, 6.16
# Position (x, y, z): 0.22, -0.45, 6.16
# Position (x, y, z): 0.22, -0.45, 6.16
# Position (x, y, z): 0.23, -0.45, 6.16
# Position (x, y, z): 0.23, -0.45, 6.16
# Position (x, y, z): 0.23, -0.45, 6.16
# Position (x, y, z): 0.23, -0.46, 6.16
# Position (x, y, z): 0.23, -0.46, 6.16
# Position (x, y, z): 0.24, -0.46, 6.16
# Position (x, y, z): 0.24, -0.46, 6.16
# Position (x, y, z): 0.24, -0.46, 6.16
# Position (x, y, z): 0.24, -0.46, 6.16
# Position (x, y, z): 0.24, -0.46, 6.16
# Position (x, y, z): 0.24, -0.45, 6.16
# Position (x, y, z): 0.25, -0.45, 6.16
# Position (x, y, z): 0.25, -0.45, 6.16
# Position (x, y, z): 0.25, -0.45, 6.16
# Position (x, y, z): 0.26, -0.45, 6.16
# Position (x, y, z): 0.26, -0.45, 6.16
# Position (x, y, z): 0.26, -0.45, 6.16
# Position (x, y, z): 0.26, -0.45, 6.16
# Position (x, y, z): 0.26, -0.45, 6.16
# Position (x, y, z): 0.26, -0.45, 6.16
# Position (x, y, z): 0.26, -0.45, 6.15
# Position (x, y, z): 0.26, -0.45, 6.15
# Position (x, y, z): 0.27, -0.45, 6.15
# Position (x, y, z): 0.27, -0.44, 6.15
# Position (x, y, z): 0.27, -0.44, 6.15
# Position (x, y, z): 0.27, -0.44, 6.15
# Position (x, y, z): 0.27, -0.44, 6.15
# Position (x, y, z): 0.28, -0.44, 6.15
# Position (x, y, z): 0.28, -0.44, 6.15
# Position (x, y, z): 0.28, -0.44, 6.15
# Position (x, y, z): 0.28, -0.44, 6.16
# Position (x, y, z): 0.29, -0.44, 6.16
# Position (x, y, z): 0.29, -0.44, 6.16
# Position (x, y, z): 0.29, -0.44, 6.16
# Position (x, y, z): 0.29, -0.44, 6.16
# Position (x, y, z): 0.29, -0.44, 6.16
# Position (x, y, z): 0.29, -0.44, 6.16
# Position (x, y, z): 0.29, -0.44, 6.16
# Position (x, y, z): 0.29, -0.44, 6.16
# Position (x, y, z): 0.30, -0.44, 6.16
# Position (x, y, z): 0.30, -0.44, 6.16
# Position (x, y, z): 0.30, -0.44, 6.16
# Position (x, y, z): 0.30, -0.45, 6.17
# Position (x, y, z): 0.30, -0.45, 6.17
# Position (x, y, z): 0.30, -0.44, 6.17
# Position (x, y, z): 0.30, -0.44, 6.16
# Position (x, y, z): 0.30, -0.44, 6.16
# Position (x, y, z): 0.30, -0.44, 6.16
# Position (x, y, z): 0.31, -0.44, 6.16
# Position (x, y, z): 0.31, -0.44, 6.16
# Position (x, y, z): 0.31, -0.44, 6.16
# Position (x, y, z): 0.31, -0.44, 6.16
# Position (x, y, z): 0.31, -0.44, 6.16
# Position (x, y, z): 0.31, -0.44, 6.16
# Position (x, y, z): 0.30, -0.44, 6.16
# Position (x, y, z): 0.30, -0.44, 6.16
# Position (x, y, z): 0.30, -0.44, 6.16
# Position (x, y, z): 0.30, -0.44, 6.16
# Position (x, y, z): 0.30, -0.44, 6.16
# Position (x, y, z): 0.30, -0.44, 6.16
# Position (x, y, z): 0.30, -0.44, 6.16
# Position (x, y, z): 0.30, -0.44, 6.16
# Position (x, y, z): 0.30, -0.44, 6.16
# Position (x, y, z): 0.31, -0.44, 6.16
# Position (x, y, z): 0.31, -0.44, 6.16
# Position (x, y, z): 0.31, -0.43, 6.16
# Position (x, y, z): 0.31, -0.43, 6.16
# Position (x, y, z): 0.31, -0.43, 6.16
# Position (x, y, z): 0.31, -0.43, 6.16
# Position (x, y, z): 0.31, -0.43, 6.16
# Position (x, y, z): 0.31, -0.43, 6.16
# Position (x, y, z): 0.31, -0.43, 6.16
# Position (x, y, z): 0.31, -0.43, 6.16
# Position (x, y, z): 0.31, -0.43, 6.16
# Position (x, y, z): 0.31, -0.44, 6.16
# Position (x, y, z): 0.31, -0.44, 6.16
# Position (x, y, z): 0.31, -0.44, 6.16
# Position (x, y, z): 0.31, -0.44, 6.16
# Position (x, y, z): 0.31, -0.44, 6.16
# Position (x, y, z): 0.31, -0.44, 6.16
# Position (x, y, z): 0.31, -0.44, 6.16
# Position (x, y, z): 0.31, -0.44, 6.16
# Position (x, y, z): 0.31, -0.44, 6.16
# Position (x, y, z): 0.31, -0.44, 6.16
# Position (x, y, z): 0.31, -0.44, 6.16
# Position (x, y, z): 0.31, -0.44, 6.16
# Position (x, y, z): 0.31, -0.44, 6.16
# Position (x, y, z): 0.31, -0.44, 6.16
# Position (x, y, z): 0.31, -0.44, 6.16
# Position (x, y, z): 0.31, -0.44, 6.16
# Position (x, y, z): 0.31, -0.44, 6.16
# Position (x, y, z): 0.31, -0.44, 6.16
# Position (x, y, z): 0.31, -0.44, 6.16
# Position (x, y, z): 0.31, -0.44, 6.16
# Position (x, y, z): 0.31, -0.43, 6.16
# Position (x, y, z): 0.31, -0.43, 6.16
# Position (x, y, z): 0.31, -0.43, 6.16
# Position (x, y, z): 0.31, -0.43, 6.16
# Position (x, y, z): 0.31, -0.43, 6.15
# Position (x, y, z): 0.31, -0.43, 6.15
# Position (x, y, z): 0.31, -0.43, 6.16
# Position (x, y, z): 0.31, -0.43, 6.16
# Position (x, y, z): 0.31, -0.43, 6.16
# Position (x, y, z): 0.31, -0.43, 6.16
# Position (x, y, z): 0.31, -0.43, 6.16
# Position (x, y, z): 0.31, -0.43, 6.16
# Position (x, y, z): 0.31, -0.43, 6.16
# Position (x, y, z): 0.31, -0.43, 6.16
# Position (x, y, z): 0.31, -0.43, 6.16
# Position (x, y, z): 0.31, -0.43, 6.16
# Position (x, y, z): 0.31, -0.43, 6.16
# Position (x, y, z): 0.31, -0.43, 6.16
# Position (x, y, z): 0.31, -0.43, 6.16
# Position (x, y, z): 0.31, -0.43, 6.16
# Position (x, y, z): 0.31, -0.43, 6.16
# Position (x, y, z): 0.32, -0.43, 6.16
# Position (x, y, z): 0.32, -0.43, 6.16
# Position (x, y, z): 0.32, -0.43, 6.16
# Position (x, y, z): 0.32, -0.43, 6.16
# Position (x, y, z): 0.32, -0.43, 6.16
# Position (x, y, z): 0.32, -0.43, 6.16
# Position (x, y, z): 0.32, -0.43, 6.16
# Position (x, y, z): 0.32, -0.43, 6.16
# Position (x, y, z): 0.32, -0.43, 6.16
# Position (x, y, z): 0.32, -0.43, 6.16
# Position (x, y, z): 0.32, -0.43, 6.16
# Position (x, y, z): 0.32, -0.43, 6.16
# Position (x, y, z): 0.32, -0.43, 6.16
# Position (x, y, z): 0.32, -0.43, 6.16
# Position (x, y, z): 0.32, -0.43, 6.16
# Position (x, y, z): 0.32, -0.43, 6.16
# Position (x, y, z): 0.32, -0.43, 6.16
# Position (x, y, z): 0.32, -0.43, 6.16
# Position (x, y, z): 0.32, -0.43, 6.16
# Position (x, y, z): 0.32, -0.43, 6.16
# Position (x, y, z): 0.32, -0.43, 6.16
# Position (x, y, z): 0.32, -0.43, 6.16
# Position (x, y, z): 0.32, -0.43, 6.16
# Position (x, y, z): 0.32, -0.43, 6.16
# Position (x, y, z): 0.32, -0.43, 6.16
# Position (x, y, z): 0.32, -0.43, 6.16
# Position (x, y, z): 0.32, -0.43, 6.16
# Position (x, y, z): 0.32, -0.43, 6.16
# Position (x, y, z): 0.32, -0.43, 6.16
# Position (x, y, z): 0.32, -0.43, 6.16
# Position (x, y, z): 0.32, -0.43, 6.16
# Position (x, y, z): 0.32, -0.43, 6.16
# Position (x, y, z): 0.32, -0.43, 6.16
# Position (x, y, z): 0.31, -0.43, 6.16
# Position (x, y, z): 0.31, -0.43, 6.16
# Position (x, y, z): 0.31, -0.43, 6.16
# Position (x, y, z): 0.31, -0.43, 6.16
# Position (x, y, z): 0.31, -0.43, 6.16
# Position (x, y, z): 0.31, -0.43, 6.16
# Position (x, y, z): 0.31, -0.43, 6.16
# Position (x, y, z): 0.31, -0.43, 6.16
# Position (x, y, z): 0.31, -0.43, 6.16
# Position (x, y, z): 0.31, -0.43, 6.16
# Position (x, y, z): 0.31, -0.43, 6.15
# Position (x, y, z): 0.31, -0.43, 6.15
# Position (x, y, z): 0.31, -0.43, 6.15
# Position (x, y, z): 0.31, -0.43, 6.15
# Position (x, y, z): 0.31, -0.43, 6.15
# Position (x, y, z): 0.31, -0.43, 6.15
# Position (x, y, z): 0.31, -0.43, 6.15
# Position (x, y, z): 0.31, -0.43, 6.15
# Position (x, y, z): 0.31, -0.43, 6.16
# Position (x, y, z): 0.31, -0.43, 6.16
# Position (x, y, z): 0.31, -0.43, 6.15
# Position (x, y, z): 0.31, -0.43, 6.15
# Position (x, y, z): 0.31, -0.43, 6.15
# Position (x, y, z): 0.31, -0.43, 6.15
# Position (x, y, z): 0.31, -0.43, 6.15
# Position (x, y, z): 0.30, -0.43, 6.15
# Position (x, y, z): 0.30, -0.43, 6.16
# Position (x, y, z): 0.30, -0.43, 6.16
# Position (x, y, z): 0.30, -0.43, 6.16
# Position (x, y, z): 0.30, -0.43, 6.16
# Position (x, y, z): 0.30, -0.43, 6.16
# Position (x, y, z): 0.30, -0.43, 6.16
# Position (x, y, z): 0.30, -0.43, 6.16
# Position (x, y, z): 0.30, -0.43, 6.16
# Position (x, y, z): 0.30, -0.43, 6.16
# Position (x, y, z): 0.30, -0.43, 6.16
# Position (x, y, z): 0.30, -0.43, 6.16
# Position (x, y, z): 0.30, -0.43, 6.16
# Position (x, y, z): 0.30, -0.43, 6.16
# Position (x, y, z): 0.30, -0.43, 6.16
# Position (x, y, z): 0.30, -0.43, 6.16
# Position (x, y, z): 0.30, -0.43, 6.16
# Position (x, y, z): 0.29, -0.43, 6.16
# Position (x, y, z): 0.29, -0.43, 6.16
# Position (x, y, z): 0.29, -0.43, 6.16
# Position (x, y, z): 0.29, -0.43, 6.16
# Position (x, y, z): 0.29, -0.43, 6.16
# Position (x, y, z): 0.29, -0.43, 6.16
# Position (x, y, z): 0.29, -0.43, 6.16
# Position (x, y, z): 0.29, -0.44, 6.16
# Position (x, y, z): 0.29, -0.44, 6.16
# Position (x, y, z): 0.28, -0.44, 6.16
# Position (x, y, z): 0.28, -0.44, 6.16
# Position (x, y, z): 0.28, -0.44, 6.16
# Position (x, y, z): 0.28, -0.43, 6.16
# Position (x, y, z): 0.28, -0.43, 6.16
# Position (x, y, z): 0.28, -0.43, 6.16
# Position (x, y, z): 0.28, -0.43, 6.16
# Position (x, y, z): 0.28, -0.44, 6.16
# Position (x, y, z): 0.28, -0.44, 6.16
# Position (x, y, z): 0.28, -0.44, 6.16
# Position (x, y, z): 0.28, -0.44, 6.16
# Position (x, y, z): 0.28, -0.44, 6.16
# Position (x, y, z): 0.28, -0.44, 6.16
# Position (x, y, z): 0.28, -0.44, 6.16
# Position (x, y, z): 0.27, -0.44, 6.16
# Position (x, y, z): 0.27, -0.44, 6.16
# Position (x, y, z): 0.27, -0.44, 6.16
# Position (x, y, z): 0.27, -0.44, 6.16
# Position (x, y, z): 0.27, -0.44, 6.16
# Position (x, y, z): 0.27, -0.44, 6.16
# Position (x, y, z): 0.27, -0.44, 6.16
# Position (x, y, z): 0.27, -0.44, 6.16
# Position (x, y, z): 0.27, -0.44, 6.16
# Position (x, y, z): 0.27, -0.44, 6.16
# Position (x, y, z): 0.27, -0.44, 6.16
# Position (x, y, z): 0.27, -0.44, 6.16
# Position (x, y, z): 0.27, -0.44, 6.16
# Position (x, y, z): 0.27, -0.44, 6.16
# Position (x, y, z): 0.27, -0.44, 6.16
# Position (x, y, z): 0.26, -0.44, 6.16
# Position (x, y, z): 0.26, -0.44, 6.16
# Position (x, y, z): 0.26, -0.44, 6.16
# Position (x, y, z): 0.26, -0.44, 6.16
# Position (x, y, z): 0.26, -0.44, 6.16
# Position (x, y, z): 0.26, -0.44, 6.16
# Position (x, y, z): 0.25, -0.44, 6.16
# Position (x, y, z): 0.25, -0.44, 6.16
# Position (x, y, z): 0.25, -0.44, 6.16
# Position (x, y, z): 0.25, -0.45, 6.16
# Position (x, y, z): 0.24, -0.45, 6.17
# Position (x, y, z): 0.24, -0.45, 6.17
# Position (x, y, z): 0.24, -0.44, 6.17
# Position (x, y, z): 0.23, -0.44, 6.16
# Position (x, y, z): 0.23, -0.44, 6.16
# Position (x, y, z): 0.23, -0.44, 6.16
# Position (x, y, z): 0.22, -0.44, 6.16
# Position (x, y, z): 0.22, -0.44, 6.17
# Position (x, y, z): 0.22, -0.44, 6.17
# Position (x, y, z): 0.22, -0.44, 6.17
# Position (x, y, z): 0.21, -0.45, 6.17
# Position (x, y, z): 0.21, -0.45, 6.17
# Position (x, y, z): 0.21, -0.45, 6.17
# Position (x, y, z): 0.21, -0.45, 6.17
# Position (x, y, z): 0.20, -0.45, 6.17
# Position (x, y, z): 0.20, -0.45, 6.17
# Position (x, y, z): 0.20, -0.45, 6.17
# Position (x, y, z): 0.19, -0.45, 6.17
# Position (x, y, z): 0.19, -0.45, 6.17
# Position (x, y, z): 0.19, -0.45, 6.17
# Position (x, y, z): 0.18, -0.45, 6.17
# Position (x, y, z): 0.18, -0.46, 6.17
# Position (x, y, z): 0.18, -0.46, 6.18
# Position (x, y, z): 0.17, -0.46, 6.18
# Position (x, y, z): 0.17, -0.47, 6.18
# Position (x, y, z): 0.17, -0.47, 6.18
# Position (x, y, z): 0.16, -0.47, 6.18
# Position (x, y, z): 0.16, -0.47, 6.18
# Position (x, y, z): 0.15, -0.47, 6.18
# Position (x, y, z): 0.15, -0.47, 6.18
# Position (x, y, z): 0.15, -0.47, 6.18
# Position (x, y, z): 0.15, -0.47, 6.18
# Position (x, y, z): 0.15, -0.47, 6.18
# Position (x, y, z): 0.14, -0.47, 6.18
# Position (x, y, z): 0.14, -0.47, 6.18
# Position (x, y, z): 0.14, -0.48, 6.18
# Position (x, y, z): 0.14, -0.48, 6.18
# Position (x, y, z): 0.14, -0.48, 6.18
# Position (x, y, z): 0.14, -0.48, 6.18
# Position (x, y, z): 0.14, -0.48, 6.18
# Position (x, y, z): 0.13, -0.48, 6.18
# Position (x, y, z): 0.13, -0.49, 6.18
# Position (x, y, z): 0.13, -0.49, 6.18
# Position (x, y, z): 0.13, -0.49, 6.18
# Position (x, y, z): 0.13, -0.50, 6.17
# Position (x, y, z): 0.13, -0.50, 6.17
# Position (x, y, z): 0.13, -0.50, 6.17
# Position (x, y, z): 0.12, -0.50, 6.17
# Position (x, y, z): 0.12, -0.50, 6.17
# Position (x, y, z): 0.12, -0.50, 6.17
# Position (x, y, z): 0.12, -0.50, 6.17
# Position (x, y, z): 0.12, -0.50, 6.17
# Position (x, y, z): 0.12, -0.50, 6.17
# Position (x, y, z): 0.12, -0.51, 6.17
# Position (x, y, z): 0.12, -0.51, 6.16
# Position (x, y, z): 0.12, -0.52, 6.16
# Position (x, y, z): 0.12, -0.52, 6.16
# Position (x, y, z): 0.12, -0.52, 6.15
# Position (x, y, z): 0.11, -0.51, 6.15
# Position (x, y, z): 0.11, -0.51, 6.15
# Position (x, y, z): 0.11, -0.50, 6.15
# Position (x, y, z): 0.10, -0.50, 6.15
# Position (x, y, z): 0.10, -0.50, 6.15
# Position (x, y, z): 0.10, -0.50, 6.15
# Position (x, y, z): 0.11, -0.50, 6.15
# Position (x, y, z): 0.11, -0.51, 6.16
# Position (x, y, z): 0.11, -0.52, 6.16
# Position (x, y, z): 0.11, -0.53, 6.16
# Position (x, y, z): 0.11, -0.53, 6.16
# Position (x, y, z): 0.11, -0.53, 6.16
# Position (x, y, z): 0.11, -0.53, 6.16
# Position (x, y, z): 0.10, -0.53, 6.16
# Position (x, y, z): 0.10, -0.53, 6.15
# Position (x, y, z): 0.10, -0.53, 6.15
# Position (x, y, z): 0.10, -0.53, 6.15
# Position (x, y, z): 0.10, -0.54, 6.15
# Position (x, y, z): 0.10, -0.54, 6.15
# Position (x, y, z): 0.10, -0.55, 6.15
# Position (x, y, z): 0.10, -0.55, 6.15
# Position (x, y, z): 0.10, -0.56, 6.14
# Position (x, y, z): 0.10, -0.56, 6.14
# Position (x, y, z): 0.10, -0.56, 6.13
# Position (x, y, z): 0.10, -0.55, 6.13
# ...
# Position (x, y, z): 1.12, -0.88, 6.02
# Position (x, y, z): 1.12, -0.88, 6.02
# Position (x, y, z): 1.12, -0.88, 6.02
# Position (x, y, z): 1.12, -0.88, 6.02
# Position (x, y, z): 1.12, -0.88, 6.01
# Position (x, y, z): 1.12, -0.88, 6.01
# Position (x, y, z): 1.12, -0.88, 6.01
# Position (x, y, z): 1.12, -0.88, 6.01
# Position (x, y, z): 1.12, -0.88, 6.01
# Position (x, y, z): 1.12, -0.88, 6.01
# Position (x, y, z): 1.12, -0.88, 6.01
# Position (x, y, z): 1.12, -0.88, 6.01
# Position (x, y, z): 1.12, -0.88, 6.01
# Position (x, y, z): 1.12, -0.89, 6.01
# Position (x, y, z): 1.12, -0.89, 6.01
# Position (x, y, z): 1.12, -0.89, 6.01
# Position (x, y, z): 1.12, -0.89, 6.01
# Position (x, y, z): 1.12, -0.89, 6.01
# Position (x, y, z): 1.12, -0.89, 6.01
# Position (x, y, z): 1.12, -0.90, 6.01
# Position (x, y, z): 1.12, -0.90, 6.01
# Position (x, y, z): 1.12, -0.90, 6.01
# Position (x, y, z): 1.12, -0.90, 6.01
# Position (x, y, z): 1.12, -0.90, 6.01
# Position (x, y, z): 1.12, -0.90, 6.01
# Position (x, y, z): 1.12, -0.91, 6.01
# Position (x, y, z): 1.12, -0.91, 6.01
# Position (x, y, z): 1.12, -0.91, 6.01
# Position (x, y, z): 1.12, -0.91, 6.01
# Position (x, y, z): 1.12, -0.91, 6.01
# Position (x, y, z): 1.12, -0.91, 6.01
# Position (x, y, z): 1.12, -0.91, 6.01
# Position (x, y, z): 1.12, -0.91, 6.01
# Position (x, y, z): 1.12, -0.92, 6.01
# Position (x, y, z): 1.12, -0.92, 6.01
# Position (x, y, z): 1.12, -0.92, 6.01
# Position (x, y, z): 1.12, -0.92, 6.01
# Position (x, y, z): 1.12, -0.92, 6.01
# Position (x, y, z): 1.12, -0.92, 6.01
# Position (x, y, z): 1.12, -0.92, 6.01
# Position (x, y, z): 1.12, -0.92, 6.01
# Position (x, y, z): 1.12, -0.92, 6.01
# Position (x, y, z): 1.12, -0.92, 6.01
# Position (x, y, z): 1.12, -0.92, 6.01
# Position (x, y, z): 1.12, -0.93, 6.01
# Position (x, y, z): 1.12, -0.93, 6.01
# Position (x, y, z): 1.12, -0.93, 6.01
# Position (x, y, z): 1.12, -0.93, 6.01
# Position (x, y, z): 1.12, -0.93, 6.01
# Position (x, y, z): 1.12, -0.93, 6.01
# Position (x, y, z): 1.12, -0.93, 6.01
# Position (x, y, z): 1.12, -0.93, 6.01
# Position (x, y, z): 1.12, -0.93, 6.01
# Position (x, y, z): 1.12, -0.93, 6.01
# Position (x, y, z): 1.12, -0.93, 6.01
# Position (x, y, z): 1.12, -0.94, 6.01
# Position (x, y, z): 1.12, -0.94, 6.01
# Position (x, y, z): 1.12, -0.94, 6.01
# Position (x, y, z): 1.12, -0.94, 6.01
# Position (x, y, z): 1.12, -0.94, 6.01
# Position (x, y, z): 1.12, -0.94, 6.01
# Position (x, y, z): 1.12, -0.94, 6.01
# Position (x, y, z): 1.12, -0.94, 6.01
# Position (x, y, z): 1.12, -0.94, 6.01
# Position (x, y, z): 1.12, -0.94, 6.01
# Position (x, y, z): 1.12, -0.94, 6.01
# Position (x, y, z): 1.12, -0.94, 6.00
# Position (x, y, z): 1.12, -0.95, 6.01
# Position (x, y, z): 1.12, -0.95, 6.01
# Position (x, y, z): 1.12, -0.95, 6.00
# Position (x, y, z): 1.12, -0.95, 6.00
# Position (x, y, z): 1.11, -0.95, 6.00
# Position (x, y, z): 1.11, -0.95, 6.00
# Position (x, y, z): 1.11, -0.95, 6.00
# Position (x, y, z): 1.11, -0.95, 6.00
# Position (x, y, z): 1.11, -0.95, 6.00
# Position (x, y, z): 1.12, -0.95, 6.00
# Position (x, y, z): 1.12, -0.95, 6.01
# Position (x, y, z): 1.12, -0.95, 6.01
# Position (x, y, z): 1.12, -0.96, 6.01
# Position (x, y, z): 1.12, -0.96, 6.01
# Position (x, y, z): 1.12, -0.96, 6.01
# Position (x, y, z): 1.12, -0.96, 6.01
# Position (x, y, z): 1.12, -0.96, 6.01
# Position (x, y, z): 1.12, -0.96, 6.01
# Position (x, y, z): 1.12, -0.96, 6.01
# Position (x, y, z): 1.12, -0.96, 6.01
# Position (x, y, z): 1.12, -0.96, 6.00
# Position (x, y, z): 1.12, -0.96, 6.00
# Position (x, y, z): 1.11, -0.96, 6.00
# Position (x, y, z): 1.11, -0.96, 6.00
# Position (x, y, z): 1.11, -0.97, 6.00
# Position (x, y, z): 1.11, -0.97, 6.00
# Position (x, y, z): 1.11, -0.97, 6.00
# Position (x, y, z): 1.11, -0.97, 6.00
# Position (x, y, z): 1.11, -0.97, 6.00
# Position (x, y, z): 1.11, -0.97, 6.00
# Position (x, y, z): 1.11, -0.97, 6.00
# Position (x, y, z): 1.11, -0.97, 6.00
# Position (x, y, z): 1.11, -0.97, 6.00
# Position (x, y, z): 1.11, -0.97, 6.00
# Position (x, y, z): 1.11, -0.98, 6.00
# Position (x, y, z): 1.11, -0.98, 6.00
# Position (x, y, z): 1.11, -0.98, 6.00
# Position (x, y, z): 1.11, -0.98, 6.00
# Position (x, y, z): 1.11, -0.98, 6.00
# Position (x, y, z): 1.11, -0.98, 6.00
# Position (x, y, z): 1.12, -0.98, 6.00
# Position (x, y, z): 1.12, -0.98, 6.00
# Position (x, y, z): 1.11, -0.98, 6.00
# Position (x, y, z): 1.11, -0.98, 6.00
# Position (x, y, z): 1.11, -0.98, 6.00
# Position (x, y, z): 1.11, -0.98, 6.00
# Position (x, y, z): 1.11, -0.98, 6.00
# Position (x, y, z): 1.11, -0.98, 6.00
# Position (x, y, z): 1.11, -0.98, 6.00
# Position (x, y, z): 1.11, -0.98, 6.00
# Position (x, y, z): 1.11, -0.98, 6.00
# Position (x, y, z): 1.11, -0.98, 6.00
# Position (x, y, z): 1.11, -0.98, 6.00
# Position (x, y, z): 1.11, -0.98, 6.00
# Position (x, y, z): 1.11, -0.98, 6.00
# Position (x, y, z): 1.11, -0.98, 6.00
# Position (x, y, z): 1.11, -0.99, 6.00
# Position (x, y, z): 1.11, -0.99, 6.00
# Position (x, y, z): 1.11, -0.99, 6.00
# Position (x, y, z): 1.11, -0.99, 6.00
# Position (x, y, z): 1.11, -0.99, 6.00
# Position (x, y, z): 1.11, -0.99, 6.00
# Position (x, y, z): 1.11, -0.99, 6.00
# Position (x, y, z): 1.11, -0.99, 6.00
# Position (x, y, z): 1.11, -0.99, 6.00
# Position (x, y, z): 1.11, -0.99, 6.00
# Position (x, y, z): 1.11, -1.00, 6.00
# Position (x, y, z): 1.11, -1.00, 6.00
# Position (x, y, z): 1.11, -1.00, 6.00
# Position (x, y, z): 1.11, -1.00, 6.00
# Position (x, y, z): 1.11, -1.00, 6.00
# Position (x, y, z): 1.11, -1.00, 6.00
# Position (x, y, z): 1.11, -1.00, 6.00
# Position (x, y, z): 1.11, -1.00, 6.00
# Position (x, y, z): 1.11, -1.00, 6.00
# Position (x, y, z): 1.10, -1.00, 6.00
# Position (x, y, z): 1.10, -1.00, 6.00
# Position (x, y, z): 1.10, -1.00, 6.00
# Position (x, y, z): 1.10, -1.00, 6.00
# Position (x, y, z): 1.10, -1.00, 6.00
# Position (x, y, z): 1.10, -1.00, 6.00
# Position (x, y, z): 1.10, -1.00, 6.00
# Position (x, y, z): 1.10, -1.00, 6.00
# Position (x, y, z): 1.10, -1.00, 6.00
# Position (x, y, z): 1.10, -1.01, 6.00
# Position (x, y, z): 1.10, -1.01, 6.00
# Position (x, y, z): 1.10, -1.01, 6.00
# Position (x, y, z): 1.10, -1.01, 6.00
# Position (x, y, z): 1.10, -1.01, 6.00
# Position (x, y, z): 1.10, -1.01, 6.00
# Position (x, y, z): 1.10, -1.01, 6.00
# Position (x, y, z): 1.10, -1.01, 6.00
# Position (x, y, z): 1.10, -1.01, 6.00
# Position (x, y, z): 1.10, -1.01, 6.00
# Position (x, y, z): 1.10, -1.01, 6.00
# Position (x, y, z): 1.10, -1.01, 6.00
# Position (x, y, z): 1.10, -1.01, 6.00
# Position (x, y, z): 1.10, -1.02, 6.00
# Position (x, y, z): 1.10, -1.02, 6.00
# Position (x, y, z): 1.10, -1.02, 6.00
# Position (x, y, z): 1.10, -1.02, 6.00
# Position (x, y, z): 1.10, -1.02, 6.00
# Position (x, y, z): 1.10, -1.02, 6.00
# Position (x, y, z): 1.10, -1.02, 6.00
# Position (x, y, z): 1.10, -1.02, 6.00
# Position (x, y, z): 1.10, -1.02, 6.00
# Position (x, y, z): 1.10, -1.02, 6.00
# Position (x, y, z): 1.10, -1.02, 6.00
# Position (x, y, z): 1.10, -1.02, 6.00
# Position (x, y, z): 1.10, -1.02, 6.00
# Position (x, y, z): 1.10, -1.02, 6.00
# Position (x, y, z): 1.10, -1.02, 6.00
# Position (x, y, z): 1.10, -1.02, 6.00
# Position (x, y, z): 1.10, -1.02, 6.00
# Position (x, y, z): 1.10, -1.02, 5.99
# Position (x, y, z): 1.09, -1.02, 5.99
# Position (x, y, z): 1.09, -1.03, 5.99
# Position (x, y, z): 1.09, -1.03, 5.99
# Position (x, y, z): 1.09, -1.03, 5.99
# Position (x, y, z): 1.10, -1.03, 5.99
# Position (x, y, z): 1.10, -1.03, 5.99
# Position (x, y, z): 1.10, -1.03, 5.99
# Position (x, y, z): 1.10, -1.03, 5.99
# Position (x, y, z): 1.10, -1.03, 5.99
# Position (x, y, z): 1.10, -1.04, 5.99
# Position (x, y, z): 1.10, -1.04, 5.99
# Position (x, y, z): 1.10, -1.04, 5.98
# Position (x, y, z): 1.10, -1.04, 5.98
# Position (x, y, z): 1.09, -1.04, 5.98
# Position (x, y, z): 1.09, -1.05, 5.97
# Position (x, y, z): 1.09, -1.05, 5.97
# Position (x, y, z): 1.09, -1.05, 5.96
# Position (x, y, z): 1.09, -1.06, 5.96
# Position (x, y, z): 1.09, -1.06, 5.95
# Position (x, y, z): 1.09, -1.07, 5.94
# Position (x, y, z): 1.08, -1.08, 5.94
# Position (x, y, z): 1.08, -1.08, 5.93
# Position (x, y, z): 1.08, -1.09, 5.91
# Position (x, y, z): 1.08, -1.10, 5.90
# Position (x, y, z): 1.08, -1.10, 5.89
# Position (x, y, z): 1.08, -1.11, 5.88
# Position (x, y, z): 1.08, -1.11, 5.87
# Position (x, y, z): 1.07, -1.11, 5.85
# Position (x, y, z): 1.07, -1.11, 5.84
# Position (x, y, z): 1.07, -1.10, 5.83
# Position (x, y, z): 1.07, -1.10, 5.82
# Position (x, y, z): 1.07, -1.09, 5.81
# Position (x, y, z): 1.07, -1.08, 5.80
# Position (x, y, z): 1.07, -1.07, 5.79
# Position (x, y, z): 1.07, -1.07, 5.79
# Position (x, y, z): 1.07, -1.05, 5.79
# Position (x, y, z): 1.07, -1.02, 5.79
# Position (x, y, z): 1.07, -1.00, 5.80
# Position (x, y, z): 1.07, -0.97, 5.80
# Position (x, y, z): 1.07, -0.94, 5.81
# Position (x, y, z): 1.08, -0.91, 5.82
# Position (x, y, z): 1.08, -0.88, 5.83
# Position (x, y, z): 1.09, -0.84, 5.84
# Position (x, y, z): 1.10, -0.81, 5.85
# Position (x, y, z): 1.10, -0.78, 5.85
# Position (x, y, z): 1.10, -0.75, 5.85
# Position (x, y, z): 1.10, -0.72, 5.84
# Position (x, y, z): 1.09, -0.69, 5.84
# Position (x, y, z): 1.09, -0.65, 5.83
# Position (x, y, z): 1.08, -0.62, 5.81
# Position (x, y, z): 1.08, -0.59, 5.81
# Position (x, y, z): 1.09, -0.56, 5.80
# Position (x, y, z): 1.09, -0.51, 5.77
# Position (x, y, z): 1.09, -0.46, 5.75
# Position (x, y, z): 1.10, -0.41, 5.72
# Position (x, y, z): 1.10, -0.34, 5.70
# Position (x, y, z): 1.12, -0.27, 5.69
# Position (x, y, z): 1.13, -0.20, 5.67
# Position (x, y, z): 1.14, -0.14, 5.65
# Position (x, y, z): 1.14, -0.07, 5.63
# Position (x, y, z): 1.14, -0.01, 5.61
# Position (x, y, z): 1.14, 0.05, 5.59
# Position (x, y, z): 1.13, 0.12, 5.57
# Position (x, y, z): 1.12, 0.18, 5.56
# Position (x, y, z): 1.11, 0.24, 5.54
# Position (x, y, z): 1.11, 0.30, 5.53
# Position (x, y, z): 1.10, 0.35, 5.52
# Position (x, y, z): 1.10, 0.40, 5.51
# Position (x, y, z): 1.09, 0.44, 5.50
# Position (x, y, z): 1.09, 0.48, 5.48
# Position (x, y, z): 1.08, 0.52, 5.46
# Position (x, y, z): 1.07, 0.56, 5.44
# Position (x, y, z): 1.07, 0.60, 5.43
# Position (x, y, z): 1.06, 0.64, 5.41
# Position (x, y, z): 1.06, 0.68, 5.40
# Position (x, y, z): 1.06, 0.72, 5.38
# Position (x, y, z): 1.05, 0.75, 5.37
# Position (x, y, z): 1.05, 0.78, 5.36
# Position (x, y, z): 1.05, 0.82, 5.34
# Position (x, y, z): 1.05, 0.85, 5.33
# Position (x, y, z): 1.05, 0.88, 5.31
# Position (x, y, z): 1.04, 0.91, 5.29
# Position (x, y, z): 1.03, 0.95, 5.27
# Position (x, y, z): 1.03, 0.98, 5.25
# Position (x, y, z): 1.02, 1.01, 5.24
# Position (x, y, z): 1.01, 1.05, 5.22
# Position (x, y, z): 0.99, 1.08, 5.20
# Position (x, y, z): 0.98, 1.12, 5.19
# Position (x, y, z): 0.96, 1.16, 5.17
# Position (x, y, z): 0.95, 1.20, 5.16
# Position (x, y, z): 0.93, 1.23, 5.14
# Position (x, y, z): 0.91, 1.27, 5.11
# Position (x, y, z): 0.89, 1.31, 5.09
# Position (x, y, z): 0.86, 1.34, 5.07
# Position (x, y, z): 0.84, 1.38, 5.04
# Position (x, y, z): 0.81, 1.42, 5.02
# Position (x, y, z): 0.79, 1.45, 4.99
# Position (x, y, z): 0.76, 1.48, 4.96
# Position (x, y, z): 0.72, 1.52, 4.93
# Position (x, y, z): 0.69, 1.57, 4.90
# Position (x, y, z): 0.65, 1.62, 4.88
# Position (x, y, z): 0.60, 1.68, 4.85
# Position (x, y, z): 0.56, 1.74, 4.82
# Position (x, y, z): 0.52, 1.80, 4.80
# Position (x, y, z): 0.48, 1.84, 4.77
# Position (x, y, z): 0.44, 1.87, 4.74
# Position (x, y, z): 0.40, 1.90, 4.71
# Position (x, y, z): 0.36, 1.92, 4.68
# Position (x, y, z): 0.32, 1.95, 4.65
# Position (x, y, z): 0.29, 1.98, 4.63
# Position (x, y, z): 0.27, 2.02, 4.61
# Position (x, y, z): 0.24, 2.06, 4.59
# Position (x, y, z): 0.22, 2.10, 4.57
# Position (x, y, z): 0.19, 2.13, 4.54
# Position (x, y, z): 0.17, 2.16, 4.52
# Position (x, y, z): 0.15, 2.19, 4.50
# Position (x, y, z): 0.13, 2.22, 4.47
# Position (x, y, z): 0.11, 2.25, 4.45
# Position (x, y, z): 0.09, 2.28, 4.43
# Position (x, y, z): 0.06, 2.31, 4.40
# Position (x, y, z): 0.03, 2.34, 4.38
# Position (x, y, z): 0.01, 2.37, 4.36
# Position (x, y, z): -0.02, 2.40, 4.34
# Position (x, y, z): -0.04, 2.43, 4.32
# Position (x, y, z): -0.07, 2.45, 4.30
# Position (x, y, z): -0.09, 2.48, 4.28
# Position (x, y, z): -0.11, 2.51, 4.26
# Position (x, y, z): -0.13, 2.53, 4.25
# Position (x, y, z): -0.15, 2.56, 4.23
# Position (x, y, z): -0.17, 2.58, 4.21
# Position (x, y, z): -0.19, 2.61, 4.19
# Position (x, y, z): -0.21, 2.63, 4.18
# Position (x, y, z): -0.23, 2.66, 4.16
# Position (x, y, z): -0.26, 2.68, 4.15
# Position (x, y, z): -0.28, 2.71, 4.13
# Position (x, y, z): -0.30, 2.73, 4.11
# Position (x, y, z): -0.32, 2.76, 4.10
# Position (x, y, z): -0.34, 2.78, 4.08
# Position (x, y, z): -0.35, 2.80, 4.06
# Position (x, y, z): -0.37, 2.83, 4.05
# Position (x, y, z): -0.39, 2.85, 4.03
# Position (x, y, z): -0.41, 2.88, 4.01
# Position (x, y, z): -0.43, 2.90, 4.00
# Position (x, y, z): -0.45, 2.92, 3.98
# Position (x, y, z): -0.47, 2.94, 3.97
# Position (x, y, z): -0.49, 2.97, 3.95
# Position (x, y, z): -0.51, 2.99, 3.94
# Position (x, y, z): -0.52, 3.01, 3.92
# Position (x, y, z): -0.54, 3.03, 3.91
# Position (x, y, z): -0.56, 3.05, 3.89
# Position (x, y, z): -0.58, 3.07, 3.88
# Position (x, y, z): -0.59, 3.10, 3.86
# Position (x, y, z): -0.61, 3.12, 3.85
# Position (x, y, z): -0.63, 3.14, 3.83
# Position (x, y, z): -0.64, 3.16, 3.82
# Position (x, y, z): -0.66, 3.18, 3.81
# Position (x, y, z): -0.68, 3.20, 3.79
# Position (x, y, z): -0.69, 3.21, 3.78
# Position (x, y, z): -0.71, 3.23, 3.76
# Position (x, y, z): -0.73, 3.25, 3.75
# Position (x, y, z): -0.74, 3.27, 3.74
# Position (x, y, z): -0.76, 3.29, 3.73
# Position (x, y, z): -0.77, 3.31, 3.71
# Position (x, y, z): -0.79, 3.33, 3.70
# Position (x, y, z): -0.80, 3.35, 3.69
# Position (x, y, z): -0.82, 3.37, 3.67
# Position (x, y, z): -0.83, 3.38, 3.66
# Position (x, y, z): -0.85, 3.40, 3.65
# Position (x, y, z): -0.86, 3.42, 3.64
# Position (x, y, z): -0.87, 3.44, 3.63
# Position (x, y, z): -0.89, 3.46, 3.61
# Position (x, y, z): -0.90, 3.47, 3.60
# Position (x, y, z): -0.92, 3.49, 3.59
# Position (x, y, z): -0.93, 3.51, 3.58
# Position (x, y, z): -0.95, 3.52, 3.56
# Position (x, y, z): -0.96, 3.54, 3.55
# Position (x, y, z): -0.98, 3.56, 3.54
# Position (x, y, z): -0.99, 3.57, 3.52
# Position (x, y, z): -1.00, 3.59, 3.51
# Position (x, y, z): -1.02, 3.61, 3.50
# Position (x, y, z): -1.03, 3.62, 3.48
# Position (x, y, z): -1.05, 3.64, 3.47
# Position (x, y, z): -1.06, 3.66, 3.46
# Position (x, y, z): -1.07, 3.67, 3.45
# Position (x, y, z): -1.09, 3.69, 3.44
# Position (x, y, z): -1.10, 3.70, 3.43
# Position (x, y, z): -1.11, 3.72, 3.42
# Position (x, y, z): -1.12, 3.73, 3.41
# Position (x, y, z): -1.14, 3.75, 3.39
# Position (x, y, z): -1.15, 3.76, 3.38
# Position (x, y, z): -1.16, 3.78, 3.37
# Position (x, y, z): -1.17, 3.79, 3.36
# Position (x, y, z): -1.18, 3.80, 3.35
# Position (x, y, z): -1.19, 3.82, 3.34
# Position (x, y, z): -1.20, 3.83, 3.33
# Position (x, y, z): -1.21, 3.84, 3.32
# Position (x, y, z): -1.23, 3.86, 3.32
# Position (x, y, z): -1.24, 3.87, 3.31
# Position (x, y, z): -1.25, 3.89, 3.30
# Position (x, y, z): -1.26, 3.90, 3.29
# Position (x, y, z): -1.27, 3.91, 3.28
# Position (x, y, z): -1.28, 3.92, 3.27
# Position (x, y, z): -1.29, 3.94, 3.27
# Position (x, y, z): -1.30, 3.95, 3.26
# Position (x, y, z): -1.30, 3.96, 3.25
# Position (x, y, z): -1.31, 3.97, 3.24
# Position (x, y, z): -1.32, 3.98, 3.23
# Position (x, y, z): -1.33, 4.00, 3.23
# Position (x, y, z): -1.34, 4.01, 3.22
# Position (x, y, z): -1.35, 4.02, 3.21
# Position (x, y, z): -1.36, 4.03, 3.20
# Position (x, y, z): -1.37, 4.05, 3.19
# Position (x, y, z): -1.38, 4.06, 3.19
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[45], line 74
#      71 # Simulation loop
#      72 while True:
#      73     # Replace `get_raw_imu()` with actual IMU data retrieval
# ---> 74     acceleration = np.array(get_raw_imu())  # Example: get acceleration data [ax, ay, az]
#      76     # Ensure the acceleration is a 3-element array (reshape if needed)
#      77     if acceleration.shape[0] != 3:
#
# Cell In[34], line 81, in get_raw_imu()
#      75 """Read raw IMU data and decode it as signed 16-bit integers.
#      76
#      77 Returns:
#      78     tuple | None: tuple - processed data, None - received data doesn't correspond to sent command
#      79 """
#      80 send_msp_message(MSP_RAW_IMU)  # send request
# ---> 81 time.sleep(0.009)  # wait for reply
#      82 response = read_msp_response()  # get reply
#      84 if response and response[0] == MSP_RAW_IMU:
#      85     # Decode as signed 16-bit integers
#
# KeyboardInterrupt:

# %%
get_raw_imu()
# Out:
# (23, 2042, 309, 1, 4, 1)
